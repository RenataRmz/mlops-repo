# %% [markdown]
# <a href="https://colab.research.google.com/github/RenataRmz/mlops-repo/blob/feature-exploration/mlops-repo/notebooks/00.Exploration/Censo_(cuestionario_b%C3%A1sico).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd

# %%
# Crear carpeta de trabajo
os.makedirs("INEGI_Censo2020", exist_ok=True)
os.chdir("INEGI_Censo2020")

# %%
# ----------------------------
# 1. Descargar los archivos
# ----------------------------
# !wget -O Censo_Personas.zip "https://www.inegi.org.mx/contenidos/programas/ccpv/2020/microdatos/Censo2020_CPV_CB_Personas_ejemplo_csv.zip"
# !wget -O Censo_Viviendas.zip "https://www.inegi.org.mx/contenidos/programas/ccpv/2020/microdatos/Censo2020_CPV_CB_Viviendas_ejemplo_csv.zip"
# !wget -O Descriptor_BD.xlsx "https://www.inegi.org.mx/contenidos/programas/ccpv/2020/microdatos/Censo2020_CPV_CB_descriptor_bd_ejemplo.xlsx"
# !wget -O Clasificaciones.zip "https://www.inegi.org.mx/contenidos/programas/ccpv/2020/microdatos/Censo2020_clasificaciones_CPV_csv.zip"
# !wget -O CIGEL.csv "https://www.inegi.org.mx/contenidos/programas/ccpv/2020/microdatos/Censo2020_CIGEL.csv"
# Out:
# --2025-08-05 02:48:02--  https://www.inegi.org.mx/contenidos/programas/ccpv/2020/microdatos/Censo2020_CPV_CB_Personas_ejemplo_csv.zip
# Resolving www.inegi.org.mx (www.inegi.org.mx)... 200.23.8.5
# Connecting to www.inegi.org.mx (www.inegi.org.mx)|200.23.8.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21447866 (20M) [application/x-zip-compressed]
# Saving to: ‘Censo_Personas.zip’
#
# Censo_Personas.zip  100%[===================>]  20.45M  2.70MB/s    in 10s
#
# 2025-08-05 02:48:12 (2.04 MB/s) - ‘Censo_Personas.zip’ saved [21447866/21447866]
#
# --2025-08-05 02:48:13--  https://www.inegi.org.mx/contenidos/programas/ccpv/2020/microdatos/Censo2020_CPV_CB_Viviendas_ejemplo_csv.zip
# Resolving www.inegi.org.mx (www.inegi.org.mx)... 200.23.8.5
# Connecting to www.inegi.org.mx (www.inegi.org.mx)|200.23.8.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7522527 (7.2M) [application/x-zip-compressed]
# ...

# %%
# ----------------------------
# 2. Descomprimir los ZIP
# ----------------------------
# !unzip -o Censo_Personas.zip -d Personas
# !unzip -o Censo_Viviendas.zip -d Viviendas
# !unzip -o Clasificaciones.zip -d Clasificaciones
# Out:
# Archive:  Censo_Personas.zip
#   inflating: Personas/Censo2020_CPV_CB_Personas_ejemplo_csv.CSV
# Archive:  Censo_Viviendas.zip
#   inflating: Viviendas/cpv2020_cb_viviendas_ej.CSV
# Archive:  Clasificaciones.zip
#   inflating: Clasificaciones/ACTIVIDAD.csv
#   inflating: Clasificaciones/CARRERA.csv
#   inflating: Clasificaciones/CAUSA_MIG.csv
#   inflating: Clasificaciones/CLASE_VIV.csv
#   inflating: Clasificaciones/ENT.csv
#   inflating: Clasificaciones/ENT_PAIS.csv
#   inflating: Clasificaciones/ESCOACUM.csv
#   inflating: Clasificaciones/INALI.csv
#   inflating: Clasificaciones/MUN.csv
#   inflating: Clasificaciones/OCUPACION.csv
#   inflating: Clasificaciones/PARENTESCO.csv
#   inflating: Clasificaciones/RELIGION.csv

# %%
# ----------------------------
# 3. Cargar CSVs y Excel
# ----------------------------
# 3.1 Cargar archivo de personas (buscar el CSV dentro de la carpeta)
personas_files = os.listdir("Personas")
personas_path = os.path.join("Personas", personas_files[0])
df_personas = pd.read_csv(personas_path, encoding="latin1")
df_personas.head()
# Out:
#    ENT  MUN  LOC  AGEB  MZA SEG        ID_VIV         ID_PERSONA  TIPO_REG  \
# 0   21  108    1  0017    1   N  211080000005  21108000000500001         0
# 1   21  108    1  0017    1   N  211080000005  21108000000500003         0
# 2   21  108    1  0017    1   N  211080000005  21108000000500002         0
# 3   14   86    1  0017    3   N  140860001428  14086000142800003         0
# 4   14   86    1  0017    3   N  140860001428  14086000142800001         0
#
#    CLASE_VIV  ...  ESCOACUM  ENT_PAIS_RES_5A  MUN_RES_5A  CAUSA_MIG_V  \
# 0        2.0  ...      15.0               21       108.0          NaN
# 1        2.0  ...       5.0               23         9.0        301.0
# 2        2.0  ...       3.0               23         9.0        301.0
# 3        3.0  ...       NaN               14        86.0          NaN
# 4        3.0  ...       9.0               14        86.0          NaN
#
#    SITUA_CONYUGAL  CONACT  HIJOS_NAC_VIVOS  HIJOS_FALLECIDOS  TAMLOC  TAMLOC14
# ...

# %%
df_personas.shape
# Out:
# (1257506, 43)

# %%
# 3.2 Cargar archivo de viviendas
viviendas_files = os.listdir("Viviendas")
viviendas_path = os.path.join("Viviendas", viviendas_files[0])
df_viviendas = pd.read_csv(viviendas_path, encoding="latin1")
df_viviendas.head()
# Out:
#    ENT  MUN  LOC  AGEB  MZA SEG        ID_VIV  TIPO_REG  CLASE_VIV  PISOS  \
# 0   14    1   24  0307   55   N  140010000001         0        1.0    2.0
# 1   14    1    1  530A    8   N  140010000002         0        1.0    2.0
# 2   14    1   25  1200    1   N  140010000003         0        1.0    2.0
# 3   14    1    1  0664   15   N  140010000004         0        2.0    3.0
# 4   14    1   81  0242    1   N  140010000005         0        1.0    3.0
#
#    ...  INTERNET  SERV_TV_PAGA  SERV_PEL_PAGA  CON_VJUEGOS  NUMPERS  TIPOHOG  \
# 0  ...       7.0           1.0            4.0          6.0        6      2.0
# 1  ...       7.0           1.0            4.0          6.0        4      1.0
# 2  ...       7.0           2.0            4.0          6.0        2      1.0
# 3  ...       7.0           1.0            4.0          6.0        2      1.0
# 4  ...       7.0           2.0            4.0          6.0        2      1.0
#
#    JEFE_SEXO  JEFE_EDAD  TAMLOC  TAMLOC14
# ...

# %%
df_viviendas.shape
# Out:
# (352368, 42)

# %%
# 3.3 Cargar descriptor de base de datos (Excel)
# df_descriptor = pd.read_excel("Descriptor_BD.xlsx")
# df_descriptor.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#    Unnamed: 0           CENSO DE POBLACIÓN Y VIVIENDA 2020   Unnamed: 2  \
# 0         NaN  DICCIONARIO DE DATOS  - CUESTIONARIO BÁSICO          NaN
# 1         NaN             CARACTERÍSTICAS DE LAS VIVIENDAS          NaN
# 2         NaN                                          NaN          NaN
# 3         NaN                              TABLA:VIVIENDAS          NaN
# 4         NaN                                          NO.  DESCRIPCIÓN
#
#   Unnamed: 3            Unnamed: 4 Unnamed: 5       Unnamed: 6 Unnamed: 7  \
# 0        NaN                   NaN        NaN              NaN        NaN
# 1        NaN                   NaN        NaN              NaN        NaN
# 2        NaN                   NaN        NaN  Segunda edición        NaN
# ...

# %%
# 3.4 Cargar clasificaciones (hay varios CSVs, vamos a cargarlos todos)
# Estos archivos se tendrían que cargar según se necesiten.
# print("Clasificaciones:")
# clasificaciones_files = os.listdir("Clasificaciones")
# for file in clasificaciones_files:
#     if file.endswith(".csv"):
#         path = os.path.join("Clasificaciones", file)
#         df_clasif = pd.read_csv(path, encoding="latin1")
#         df_clasif.head()
# Out:
# Clasificaciones:

# %%
# 3.5 Cargar archivo CIGEL (csv plano)
df_cigel = pd.read_csv("CIGEL.csv", encoding="latin1")
df_cigel.head()
# Out:
#    cve_ent  cve_mun  cve_loc cve_ageb                 nom_loc tipo plano  \
# 0        1        1        1     0000          Aguascalientes    U     S
# 1        1        1       94     1068          Granja Adelita    R     N
# 2        1        1       96     1759               Agua Azul    R     C
# 3        1        1      100     1759           Rancho Alegre    R     N
# 4        1        1      102     1123  Los Arbolitos [Rancho]    R     N
#
#            longitud          latitud altitud         ccl_x         ccl_y  \
# 0  102°17'45.768 W"  21°52'47.362 N"    1878  2.469558e+06  1.095910e+06
# 1  102°22'24.710 W"  21°52'18.749 N"    1902  2.461588e+06  1.095053e+06
# 2  102°21'25.639 W"  21°53'01.522 N"    1861  2.463279e+06  1.096358e+06
# 3  102°22'21.884 W"  21°51'16.556 N"    1879  2.461664e+06  1.093150e+06
# 4  102°21'26.261 W"  21°46'48.650 N"    1861  2.463232e+06  1.084947e+06
#
#    long_dec  lat_dec cve_carta
# 0 -102.2960  21.8798    F13D19
# ...
