# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardoArion/mlops-repo/blob/feature-gobcdmx/Catastral_explore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Archivo Catastral

# %% [markdown]
# En su momento subí directamente los archivos a google colab, y desde el historial de uploads los llamé para hacer el concat, deberé modificar este pedazo de código una vez establezcamos donde almacenaremos lo datos

# %%
catastral = list(uploaded.keys())
print(uploaded.keys())
# Out:
# dict_keys(['catastro2021_ALVARO_OBREGON.csv', 'catastro2021_AZCAPOTZALCO.csv', 'catastro2021_BENITO_JUAREZ.csv', 'catastro2021_COYOACAN.csv', 'catastro2021_CUAJIMALPA.csv', 'catastro2021_CUAUHTEMOC.csv', 'catastro2021_GUSTAVO_A_MADERO.csv', 'catastro2021_IZTACALCO.csv', 'catastro2021_IZTAPALAPA.csv', 'catastro2021_MAGDALENA_CONTRERAS.csv', 'catastro2021_MIGUEL_HIDALGO.csv', 'catastro2021_MILPA_ALTA.csv', 'catastro2021_TLAHUAC.csv', 'catastro2021_TLALPAN.csv', 'catastro2021_VENUSTIANO_CARRANZA.csv', 'catastro2021_XOCHIMILCO.csv'])

# %%
df_catastral = [pd.read_csv(nombre) for nombre in catastral]
df_final_catastral = pd.concat(df_catastral, axis=0, ignore_index=True)
# Out:
# /tmp/ipython-input-2182653453.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_catastral = [pd.read_csv(nombre) for nombre in catastral]

# %%
# Guardar en CSV
df_final_catastral.to_csv("concat_catastral.csv", index=False)

# Descargar
files.download("concat_catastral.csv")

# %% [markdown]
# Voy a verificar que no haya peridido filas en el concat y asi fue, no perdí ni una sola
# Total filas en todos los archivos: 2295465
# Filas en df_final: 2295465

# %%
import pandas as pd

# Supongamos que ya tienes la lista de nombres
archivos = list(uploaded.keys())

# Leer y contar filas de cada archivo
total_filas = 0
for archivo in archivos:
    df = pd.read_csv(archivo)
    filas = len(df)
    total_filas += filas
    print(f"{archivo}: {filas} filas")

print("Total filas en todos los archivos:", total_filas)

# Ahora cuentas en el df_final
print("Filas en df_final:", len(df_final_catastral))
# Out:
# /tmp/ipython-input-4063968483.py:9: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(archivo)
# catastro2021_ALVARO_OBREGON.csv: 180377 filas
# catastro2021_AZCAPOTZALCO.csv: 113617 filas
# catastro2021_BENITO_JUAREZ.csv: 216309 filas
# catastro2021_COYOACAN.csv: 168159 filas
# catastro2021_CUAJIMALPA.csv: 52753 filas
# catastro2021_CUAUHTEMOC.csv: 246722 filas
# catastro2021_GUSTAVO_A_MADERO.csv: 245885 filas
# catastro2021_IZTACALCO.csv: 99684 filas
# catastro2021_IZTAPALAPA.csv: 366324 filas
# catastro2021_MAGDALENA_CONTRERAS.csv: 38033 filas
# catastro2021_MIGUEL_HIDALGO.csv: 170338 filas
# catastro2021_MILPA_ALTA.csv: 10216 filas
# catastro2021_TLAHUAC.csv: 67652 filas
# catastro2021_TLALPAN.csv: 139958 filas
# catastro2021_VENUSTIANO_CARRANZA.csv: 120801 filas
# catastro2021_XOCHIMILCO.csv: 58637 filas
# Total filas en todos los archivos: 2295465
# Filas en df_final: 2295465

# %% [markdown]
# Ahora haré un merge de mis dos archivos, concat_catastral.csv y AGEB_fm

# %% [markdown]
# Lo que noto es que al intentar hacer el merge con nombres voy a tener problemas con las calles que sea del estilo
# calle: "Sur 170", número: 7 --> Sur 170 7
# Sostenes Rocha Gral 73 a
# Sostenes Rocha S/n Esq. Sur 122
# SUR 112 S N
# Sur 112 a Num 19
# Y demás ejemplos, es como aparece en mis datos, entonces creo que lo que deberé hacer es separar el nombre del numero por el primer espacio que haya de derecha a izquierda para así generar una sola columna que me de solo el nombre y esta la pueda unir a
#
# NOMVIAL en AGEB_fm
#
# Yo se que de este manera perderé datos si intento hacer un match exacto, por lo que tendré que hacer un merge con aproximaciones del nombre, por ejemplo con un startswith()
#
# tambien voy a agregar una etiqueta ("_cat") a los datos de concat_catastral que se sumen a AGEB_fm

# %% [markdown]
# Primero le daré tratamiento al df de catastral para crear el nombre de la calle, el cual sera mi llave de merge

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/TFM/concat_catastral.csv" /content/
df_catastral = pd.read_csv("concat_catastral.csv")  # ahora carga más rápido

# !cp "/content/drive/MyDrive/TFM/AGEB_fm.csv" /content/
df_AGEB_fm = pd.read_csv("AGEB_fm.csv")  # ahora carga más rápido
# Out:
# /tmp/ipython-input-3051520690.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_catastral = pd.read_csv("concat_catastral.csv")  # ahora carga más rápido
# /tmp/ipython-input-3051520690.py:5: DtypeWarning: Columns (6,50,104,111,112,116,117) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_AGEB_fm = pd.read_csv("AGEB_fm.csv")  # ahora carga más rápido

# %%
df_catastral.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2295465 entries, 0 to 2295464
# Data columns (total 14 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   fid                   float64
#  1   fid_2                 float64
#  2   calle_numero          object
#  3   codigo_postal         object
#  4   colonia               object
#  5   alcaldia              object
#  6   sup_terreno           float64
#  7   sup_construccion      float64
#  8   anio_construccion     float64
#  9   instal_esp            int64
#  10  valor_unitario_suelo  float64
#  11  valor_suelo           float64
#  12  cve_vus               object
#  13  subsidio              float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 245.2+ MB

# %%
df_catastral["calle_numero"] = df_catastral["calle_numero"].astype(str)

df_catastral["calle_numero"] = df_catastral["calle_numero"].fillna("").astype(str)

# %%
type(df_catastral["calle_numero"].iloc[0])
# Out:
# str

# %%
"""
import re
import unicodedata

def normalizar_calle(texto: str) -> str:
    """
    Normaliza nombres de calles eliminando ruido común (Num, Dpto, Edif, Casa, etc.)
    y conservando solo el nombre principal y número base de la calle.
    """

    if not texto or not isinstance(texto, str):
        return ""

    # --- 1. Normalización básica ---
    # Pasar a mayúsculas
    t = texto.upper()

    # Quitar acentos y caracteres raros
    t = ''.join(
        c for c in unicodedata.normalize('NFKD', t)
        if not unicodedata.combining(c)
    )

    # Uniformizar abreviaturas comunes
    reemplazos = {
        r"\bCL\.?\b": "CALLE",
        r"\bCLL\.?\b": "CALLE",
        r"\bAVD?\.?\b": "AVENIDA",
        r"\bAV\.?\b": "AVENIDA",
        r"\bCD?A\.?\b": "CDA",
        r"\bCALZ\.?\b": "CALZADA",
        r"\bEJE\b": "EJE",
        r"\bPTE\b": "PONIENTE",
        r"\bNTE\b": "NORTE",
        r"\bOTE\b": "ORIENTE",
        r"\bSUR\b": "SUR",
        r"\bDR\.?\b": "DOCTOR",
        r"\bGRAL\.?\b": "GENERAL",
        r"\bING\.?\b": "INGENIERO",
    }
    for patron, repl in reemplazos.items():
        t = re.sub(patron, repl, t)

    # --- 2. Eliminar ruido ---
    ruido = [
        r"\bNUM(ERO)?\.?\b",
        r"\bNO\.?\b",
        r"\bN\.?\b",
        r"\bDEP(TO)?\.?\b",
        r"\bDEPARTAMENTO\b",
        r"\bCASA\b",
        r"\bED(IF)?\.?\b",
        r"\bEDIFICIO\b",
        r"\bTORRE\b",
        r"\bCOND(OMINIO)?\b",
        r"\bCONJ(UNTO)?\b",
        r"\bSECC?\.?\b",
        r"\bSEC\.?\b",
        r"\bMZ\.?\b",
        r"\bMANZANA\b",
        r"\bLT\.?\b",
        r"\bLOTE\b",
        r"\bINT\.?\b",
        r"\bINTERIOR\b",
        r"\bENT\.?\b",
        r"\bAND\.?\b",
        r"\bGRUPO\b",
        r"\bAGRUP\b",
        r"\bPASEO\b",
        r"\bEST(AC)?\.?\b",
        r"\b#",
    ]
    for patron in ruido:
        t = re.sub(patron, "", t)

    # --- 3. Limpieza de caracteres ---
    t = re.sub(r"[^A-Z0-9\s]", " ", t)  # quitar símbolos
    t = re.sub(r"\s+", " ", t)          # espacios extra
    t = t.strip()

    # --- 4. Correcciones contextuales ---
    # Quitar letras sueltas al final de "SUR 114 A" → "SUR 114"
    t = re.sub(r"\b(SUR|NORTE|ORIENTE|PONIENTE|EJE \d+)\s+(\d+)[A-Z]\b", r"\1 \2", t)

    # "CALLE 6" sin número → mantener "CALLE 6"
    # "CALLE 6, 106" → "CALLE 6 106"
    t = re.sub(r"\bCALLE\s+(\d+)\s*,?\s*(\d+)", r"CALLE \1 \2", t)

    # --- 5. Output final ---
    return t

"""

# %%
# Aplicar la función a la columna calle_numero
df_catastral["calle_norm"] = df_catastral["calle_numero"].apply(normalizar_calle)

# %%
df_catastral.head(1000)
# Out:
#        fid      fid_2                        calle_numero codigo_postal  \
# 0      1.0  1966352.0                    Observatorio 297        1120.0
# 1      2.0  1966365.0                    Observatorio 299        1120.0
# 2      3.0  1966359.0                      Poniente 79 67        1120.0
# 3      4.0    96480.0                    Observatorio 301        1120.0
# 4      5.0  1966363.0                    Observatorio 305        1120.0
# ..     ...        ...                                 ...           ...
# 995  540.0  2518111.0   And. ESTRELLA DE BELEN, MZ-A LT-7        1220.0
# 996  541.0  2521327.0         AV VASCO DE QUIROGA M-F L-9        1220.0
# 997  542.0  2521515.0            ESTRELLA FUGAZ M-E JTO13        1220.0
# 998  543.0  2521305.0  Andador Estrella Blanca Mz.g Lt.31        1210.0
# 999  544.0   903595.0                          Polvora 52        1210.0
#
#          colonia        alcaldia  sup_terreno  sup_construccion  \
# 0           Cove  ALVARO OBREGON       159.58            249.35
# 1           Cove  ALVARO OBREGON       171.81            252.26
# 2           Cove  ALVARO OBREGON       180.00            141.00
# 3           Cove  ALVARO OBREGON       176.31             28.58
# 4           Cove  ALVARO OBREGON       200.00            337.00
# ..           ...             ...          ...               ...
# 995  LA ESTRELLA  ALVARO OBREGON        73.66            173.38
# 996     CUEVITAS  ALVARO OBREGON        83.00            142.45
# 997     CUEVITAS  ALVARO OBREGON        89.00            177.40
# 998     Estrella  ALVARO OBREGON        84.00             14.00
# 999     Santa Fe  ALVARO OBREGON        89.00            147.00
#
#      anio_construccion  instal_esp  valor_unitario_suelo  valor_suelo  \
# 0               2001.0           1               2604.93  415694.7294
# 1               1969.0           0               2604.93  447553.0233
# 2               1970.0           0               2604.93  468887.4000
# 3               1970.0           1               2604.93  459275.2083
# 4               1997.0           0               2604.93  520986.0000
# ..                 ...         ...                   ...          ...
# 995             2009.0           1               2355.49  173505.3934
# 996             2004.0           0               2355.49  195505.6700
# 997             1996.0           0               2355.49  209638.6100
# 998             1996.0           0               2355.49  197861.1600
# 999             1966.0           0               3155.52  280841.2800
#
#      cve_vus    subsidio                          calle_norm
# 0    A010513  644.260919                    OBSERVATORIO 297
# 1    A010513  746.544515                    OBSERVATORIO 299
# 2    A010513  643.418583                         PONIENTE 79
# 3    A010513  615.591443                    OBSERVATORIO 301
# 4    A010513  593.403316                    OBSERVATORIO 305
# ..       ...         ...                                 ...
# 995  A010541  698.719263     AND ESTRELLA DE BELEN MZ-A LT-7
# 996  A010541  566.796447         AV VASCO DE QUIROGA M-F L-9
# 997  A010541  668.010590            ESTRELLA FUGAZ M-E JTO13
# 998  A010541  197.150504  ANDADOR ESTRELLA BLANCA MZ G LT 31
# 999  A011062  504.385676                          POLVORA 52
#
# [1000 rows x 15 columns]

# %%
# Mostrar el texto completo en cada columna (sin cortar)
pd.set_option("display.max_colwidth", None)

# (Opcional) Si además quieres ver todas las filas y columnas:
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)


#print(df_catastral[["calle_numero", "calle_norm"]].head(1000).to_string())
print(df_catastral[["calle_numero", "calle_norm"]].sample(n=1000, random_state=200).to_string())

pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option("display.max_colwidth")


Eje 5 SUR AV SAN ANTONIO, 455 Edif. STAR SAN ANTONIO II, Dpto. 816                                                    EJE 5
EJE 1 PONIENTE GRO. N. 202  Est. 28                                                    EJE 1
EJE 7-A SUR GRAL. EMILIANO ZAPATA 252 DEPTO 414                                                    EJE 7
Eje 1 PONIENTE CALZ VALLEJO, 1268 Edif. E-4, Sec. COND 4, Dpto. 102                                                    EJE 1
Eje 6 SUR INDEPENDENCIA, 176 PH 2                                                    EJE 6
EJE 2 OTE CALZADA DE LA VIGA, 996 Casa H-13                                                    EJE 2
EJE 2 OTE CALZADA DE LA VIGA, 369 Dpto. 608                                                    EJE 2
EJE 2 OTE CALZADA DE LA VIGA, 1225 Dpto. 207                                                    EJE 2
Eje 5 SUR AV SAN ANTONIO, 455 Edif. STAR SAN ANTONIO II, Dpto. 816                                                    EJE 5
Avd. LOMAS DE PLATEROS, 11 Sec. ESTAC 4, Cjon. 30                                                  AVENIDA
Eje 1 PONIENTE CALZ VALLEJO, 1268 Edif. E-4, Sec. COND 4, Dpto. 102                                                    EJE 1
Eje 6 SUR INDEPENDENCIA, 176 PH 2                                                    EJE 6
AV SANTA FE 459 DEPTO 2204                                                  AVENIDA
# Out:
#                                                                    calle_numero                                               calle_norm
# 1184479                                           Trebol Mz 2 Lt 20 B Pradera I                                                   TREBOL
# 1914272                                              AV.RENO 40 EDIF.B D.T. 302                                          AVENIDA RENO 40
# 84343                                                 Cerrada de Hidalgo Num.14                                CERRADA DE HIDALGO NUM 14
# 802923                                                Tuxpan 6 Oficina 201 Roma                                TUXPAN 6 OFICINA 201 ROMA
# 795716                                                                  Tula 31                                                  TULA 31
# 1082391                                                          Pernambuco 891                                           PERNAMBUCO 891
# 1412341                                            Calle 2 225 Edif.a Depto.103                                              CALLE 2 225
# 195985                                            And 5 de Junio de 1878 No 1 a                              AND 5 DE JUNIO DE 1878 NO 1
# 1416115             EJE 8 SUR CALZADA ERMITA IZTAPALAPA, 392 Edif. W, Dpto. 301                                                    EJE 8
# 1322451                                                 Cl. COCHIMI, MZ-4 LT-40                                            CALLE COCHIMI
# 1748255                                        CJON DE SAN JOAQUIN 13 DEPTO-103                                   CJON DE SAN JOAQUIN 13
# 255096                                               NUBIA N. 258  Depto. A-139                                          NUBIA NORTE 258
# 585654                                      Avd. AZTECAS, 215 Ent. B, Dpto. 116                                      AVENIDA AZTECAS 215
# 1700862                                             AV SAN JERONIMO 1617 CASA 3                                AVENIDA SAN JERONIMO 1617
# 1786831             Cl. LAGUNA DEL CARMEN, 38 Edif. TORRE II CENTRAL, Dpto. 401                               CALLE LAGUNA DEL CARMEN 38
# 211127                                               ESPERANZA 61 MZA M CASA 09                                         ESPERANZA 61 MZA
# 1458376                                        Dora 118 San Lorenzo Xicotencatl                         DORA 118 SAN LORENZO XICOTENCATL
# 1850166                                                            Herschel 131                                             HERSCHEL 131
# 854995                                          ANTONIO CASO N. 169  Depto. 411                                   ANTONIO CASO NORTE 169
# 1913035                                                       JACINTO ISLAS L20                                            JACINTO ISLAS
# 2247973                      Div del Norte 5234 Ap An Bloque B 101 San Bernardi         DIV DEL NORTE 5234 AP AN BLOQUE 101 SAN BERNARDI
# 867548                                 Cl. GRAL MIGUEL ALEMAN, 10 Local c. A-53                     CALLE GRAL MIGUEL ALEMAN 10 LOCAL 53
# 1403949                                                       SUR 25 M-44 L-466                                            SUR 25 44 466
# 563265                                                                   Ohio 9                                                   OHIO 9
# 2220192                                         Cl. BELLAS ARTES, 298 Dpto. 101                                   CALLE BELLAS ARTES 298
# 854230                       Manuel Maria Contreras 96 Local Com Unico San Rafa       MANUEL MARIA CONTRERAS 96 LOCAL COM UNICO SAN RAFA
# 1919022                                            Porvenir 287 Edi.2 Depto.202                                       PORVENIR 287 EDI 2
# 1937625                                                  Av del Mar Lt 5 Mz 133                                          AVENIDA DEL MAR
# 1485959                                     Santiago de la Vega Mz.33 Lt.3 Zn.1                                      SANTIAGO DE LA VEGA
# 196879                                       Gustavo Garmendia Edif H Depto 103                                        GUSTAVO GARMENDIA
# 390511                                     Cl. ERNESTINA LARRAINZAR, 11 Dpto. 2                            CALLE ERNESTINA LARRAINZAR 11
# 1482844                Avd. FUERTE DE LORETO, 423 Edif. F, Sec. MZ-B, Dpto. 005                             AVENIDA FUERTE DE LORETO 423
# 509096                                                 Cl. NEVADO, 52 Dpto. 801                                          CALLE NEVADO 52
# 1966256                                          Avd. TLAHUAC TULYEHUALCO, 8470                         AVENIDA TLAHUAC TULYEHUALCO 8470
# 1611279                                                      Manuel M Prieto 72                                         MANUEL PRIETO 72
# 489252                                       Victor Hugo 12 Dpto 104 Portales 0                                           VICTOR HUGO 12
# 558757                                  Paseo de Granados Mz.29 Lt.7 Depto. 201                                        PASEO DE GRANADOS
# 328739                                              AVENIDA 3 NUM. 131 ESTAC. 2                                        AVENIDA 3 NUM 131
# 109755                                                 Cl. CIRUELO, MZ-12 LT-27                                            CALLE CIRUELO
# 1613775                                           Insurgentes Z 01 Mz 102 Lt 17                                           INSURGENTES 01
# 1470889                      Lt 3 Mz 13 Casa C Secc 4 Unidad Ejercito de Orient
# 1556600                               Hda.sn.nicolas T.29 Zafiro Edif.26 Dt.402                                 HDA SN NICOLAS 29 ZAFIRO
# 576190                                                            Crisantema 73                                            CRISANTEMA 73
# 589815                                                     Retorno 19 13 Avante                                     RETORNO 19 13 AVANTE
# 1080795                                           PERNAMBUCO NO. 801 DEPTO. 301                                        PERNAMBUCO NO 801
# 210774                          Eje 4 NTE REFINERIA AZCAPOTZALCO, 235 Dpto. 219                                                    EJE 4
# 439329                                           AV CUAUHTEMOC 1018 DEPTO B 403                                  AVENIDA CUAUHTEMOC 1018
# 1179954                                                   Puerto de Acapulco 40                                    PUERTO DE ACAPULCO 40
# 1022312                                   And 5 Rio Sta Maria Casa 100 B Zona 2                                      AND 5 RIO STA MARIA
# 1777112                                   LAGO CUPATITZIO N. 55 BIS  Depto. 101                             LAGO CUPATITZIO NORTE 55 BIS
# 1305886                                              Aguamiel Edif 27 Depto 402                                                 AGUAMIEL
# 2208130                                             IZTACCIHUATL 26 DEPTO D-205                                          IZTACCIHUATL 26
# 1426544                           Cl. BATALLONES ROJOS, 205 Edif. 49, Dpto. 501                               CALLE BATALLONES ROJOS 205
# 1865168                                                SHAKESPEARE 12 DEPTO 202                                           SHAKESPEARE 12
# 1852964                              P de las Palmas Bodega 506 Plaza Sot 3 885               P DE LAS PALMAS BODEGA 506 PLAZA SOT 3 885
# 1797043                       BLVD M DE CERVANTES SAAVEDRA No 171 S-4 CLOSET 11            BLVD DE CERVANTES SAAVEDRA NO 171 4 CLOSET 11
# 776593                          Francisco Diaz Covarrubias 100 Edif B Depto 203                           FRANCISCO DIAZ COVARRUBIAS 100
# 1838188                             Bulevar Manuel Avila Camacho 166 Depto 1102                         BULEVAR MANUEL AVILA CAMACHO 166
# 1127453                                          San Felipe de Jesus Lt 3 Mz 22                                      SAN FELIPE DE JESUS
# 1789693                                          Laguna del Carmen 146 Depto 21                                    LAGUNA DEL CARMEN 146
# 638666                       Edif 18 Depto 32 And G Bo B Alianza Popular Revolu
# 1900021                                                  VICTORIANO CORRALES 11                                   VICTORIANO CORRALES 11
# 324856                    Cl. MONTECITO, 38 Edif. COND 11, Ent. PISO 32, Ofi. 3                                       CALLE MONTECITO 38
# 1294621                                                            Sur 169 2103                                             SUR 169 2103
# 626962                            Miguel Angel Preciat Lt 24 Mz 16 los Cipreses                                     MIGUEL ANGEL PRECIAT
# 2210378                                              Fdo Lopez Arias Mz 4 Lt 13                                          FDO LOPEZ ARIAS
# 1473025                                   Huitzilin # 55 Cond-m Edif-6 Dpto-201                                           HUITZILIN # 55
# 515274                                                                Morelo 44                                                MORELO 44
# 1587973                                   Av. Tlahuac Num. 4522 Secc. a Casa 61                            AVENIDA TLAHUAC NUM 4522 SECC
# 543000                         Av Iman 580 Rin Puertos Edif Vancouver Depto 204                             AVENIDA IMAN 580 RIN PUERTOS
# 1690060                                                        Banderilla 9 Cda                                         BANDERILLA 9 CDA
# 1712157                                                          Cl. ALDAMA, 27                                          CALLE ALDAMA 27
# 120930                                      Insurgentes Sur 1971 Caracol e Stac                        INSURGENTES SUR 1971 CARACOL STAC
# 1735654                         CALZ MEXICO TACUBA 1523 EDIF BELGRADO DEPTO 602                               CALZADA MEXICO TACUBA 1523
# 1321717                                                  Oriente 132 Lt 9 Mz 27                                              ORIENTE 132
# 1250545   Cl. ORIENTE 237, 152 Edif. SUBCONDOMINIO 1 TORRE A, Ent. B, Dpto. 202                                    CALLE ORIENTE 237 152
# 2001894                                                        Tekit Mz 50 Lt 9                                                    TEKIT
# 1893995                             HEROES DE PADIERNA NUM. 30 DEPARTAMENTO 304               HEROES DE PADIERNA NUM 30 DEPARTAMENTO 304
# 2034980                                                   Av. Ahualulcos Num.60                                AVENIDA AHUALULCOS NUM 60
# 961047                     DOCTOR JOSE MARIA VERTIZ Num. 426 Departamento A-605            DR JOSE MARIA VERTIZ NUM 426 DEPARTAMENTO 605
# 1706063                                                                 NUBE 27                                                  NUBE 27
# 1106299                                                            Huasteca 217                                             HUASTECA 217
# 1644562                                                   IGNACIO VALDIVIA L-12                                      IGNACIO VALDIVIA 12
# 1871858                                                   Constituyentes 91 501                                    CONSTITUYENTES 91 501
# 1021017                      Andador 31 34 Ent a Depto 302 Acueducto de Guadalu                                            ANDADOR 31 34
# 1374527                                                              Pajares183                                               PAJARES183
# 592287                                  Calle Sin Nombre Edif 3 Ent B Depto 102                                         CALLE SIN NOMBRE
# 393457                                       Cl. HERIBERTO FRIAS, 208 Dpto. 403                                CALLE HERIBERTO FRIAS 208
# 381306                                         Cl. SATURNINO HERRAN, 127 PH 501                        CALLE SATURNINO HERRAN 127 PH 501
# 1960251                                                      SIMON ALVAREZ L-21                                         SIMON ALVAREZ 21
# 2011347                                             Priv. Insurgentes #10 Int.5                               PRIV INSURGENTES #10 INT 5
# 436446                                            Enrique Rebsamen 1141 Depto 4                                    ENRIQUE REBSAMEN 1141
# 1882206                                          Cl. ANTONIO MACEO, 8 Dpto. 501                                    CALLE ANTONIO MACEO 8
# 690058                                            2 Cda Adolfo Lopez Mateos S/n                          2 CDA ADOLFO LOPEZ MATEOS NORTE
# 1913099                                     Prolg. Miguel Hidalgo Mz. 4 Lt. 146                                     PROLG MIGUEL HIDALGO
# 337480                                           Cl. MIGUEL ANGEL, 82 Dpto. 403                                    CALLE MIGUEL ANGEL 82
# 1645278                                     Callejon Fermin Apeszeche Mz 4 Lt 5                                CALLEJON FERMIN APESZECHE
# 129711                                          AND RCHO RENACIMIENTO MZ E LT 9                                    AND RCHO RENACIMIENTO
# 1784974                                      Cl. LAGO DE CHALCO, 62 Dpto. A-302                                  CALLE LAGO DE CHALCO 62
# 573994                                                 Prof A. Reza Lt 36 Mz 01                                                PROF REZA
# 376795                                                  Amores 1636 Depto a 102                                              AMORES 1636
# 223834                              Cl. SOLEDAD, 266 Edif. E COND 2, Dpto. E103                                        CALLE SOLEDAD 266
# 1890169                                     Av Paseo de la Reforma 2620 Local 3                 AVENIDA PASEO DE LA REFORMA 2620 LOCAL 3
# 1062047                                                   Anillo Periferico 130                                    ANILLO PERIFERICO 130
# 599776                                                                Grama 103                                                GRAMA 103
# 1773779                                      Presa Salinillas Edif 45 Depto 402                                         PRESA SALINILLAS
# 1580115                        Calz. SAN LORENZO, 151 COND A-1 EDIF 3 DEPTO 404                                  CALZADA SAN LORENZO 151
# 576752                              Calz de Tlalpan Esq Ave 3 Edif 4 a Depto 34                             CALZADA DE TLALPAN ESQ AVE 3
# 1148270                                            Norte 94 a 8520 la Esmeralda                               NORTE 94 8520 LA ESMERALDA
# 2025117                                 Fuentes Brotantes Edificio I 8 Dpto 102                                        FUENTES BROTANTES
# 2107743                                    4A CDA CAMINO VIEJO A SAN ANDRES L-9                         4A CDA CAMINO VIEJO SAN ANDRES 9
# 1885080                                           AGRICULTURA N. 39  Depto. 202                                     AGRICULTURA NORTE 39
# 31773                                     Av Centenario 1209 Estacionamiento 74               AVENIDA CENTENARIO 1209 ESTACIONAMIENTO 74
# 1792923                       Cl. LAGO ANDROMACO, 104 Edif. TORRE B, Dpto. 1408                                 CALLE LAGO ANDROMACO 104
# 328787                                                    Calle 19 99 Depto 202                                              CALLE 19 99
# 773541                                        TENOCHTITLAN 137 EDIF 3 DEPTO 502                                         TENOCHTITLAN 137
# 402293                         CALZADA DE TLALPAN, 550 Edif. TORRE D, Dpto. 501                                   CALZADA DE TLALPAN 550
# 91293                         Avd. LOMAS DE PLATEROS, 11 Sec. ESTAC 3, Cjon. 43                                                  AVENIDA
# 1828529           Cl. LAGO ALBERTO, 300 Edif. TORRE 4C, Sec. FASE 2, Dpto. 2014                                   CALLE LAGO ALBERTO 300
# 1355940                                                    CIRUJANOS 30 DEPTO 7                                             CIRUJANOS 30
# 393377                                                 Enrique Rebsamen 249 101                                 ENRIQUE REBSAMEN 249 101
# 1270626                                          And Diaz de la Vega Mz 6a Lt 7                                      AND DIAZ DE LA VEGA
# 2018474                                                            KINCHIL L-14                                               KINCHIL 14
# 981573                                         Guty Cardenas Z-04 Mz.97 Lt.14-a                                         GUTY CARDENAS 04
# 1965114                                                      4 CJON GALEANA L18                                           4 CJON GALEANA
# 1170023                        Calz.sn.j.de Aragon 544 C-20 Torre Sevilla D-304                              CALZADA SN DE ARAGON 544 20
# 456131                                                  LUIS BRAILE 251 DEPTO 3                                          LUIS BRAILE 251
# 1976632                      Camino a Sta Teresa 13 Edif 7 Dpto 1903 H de Padie                                     CAMINO STA TERESA 13
# 232311                                                             San Mateo 67                                             SAN MATEO 67
# 856642                                                       Alfonso Herrera 98                                       ALFONSO HERRERA 98
# 2257990                                             Av de los Arcos Oriente 306                         AVENIDA DE LOS ARCOS ORIENTE 306
# 1113740                                                  Euzkadi 10 Depto a 202                                               EUZKADI 10
# 1860199                               Avd. CAMPOS ELISEOS, 345 Estac. 3 CJON 18                               AVENIDA CAMPOS ELISEOS 345
# 1525509                                                   Anillo Periferico 137                                    ANILLO PERIFERICO 137
# 278248                                   Ferrocarril Central 594 Ed 2 Depto 303                             FERROCARRIL CENTRAL 594 ED 2
# 1450688                                                          Justina No.114                                           JUSTINA NO 114
# 2138546                                                Herreros 20 Depto. 202-a                                              HERREROS 20
# 679833                                  Cmo. AL OLIVO, 114 Edif. E-1, Dpto. 301                                         CMO AL OLIVO 114
# 1451190                                And Loreto Lamanza Sup Mz 1 Mz 64 Lt 4 7                                   AND LORETO LAMANZA SUP
# 239862                                                Campo Fortuna Nacional 97                                CAMPO FORTUNA NACIONAL 97
# 1871882                                                    GRAL CANO 8 FEPTO 12                                     GRAL CANO 8 FEPTO 12
# 1667465                                     Nardos Lt 18 Mz 9 Consejo Agrarista                                                   NARDOS
# 1945904                                        Constitucion 30 Edif e Depto 302                                          CONSTITUCION 30
# 1037817                                                  DE LOS ACANTILADOS L51                                       DE LOS ACANTILADOS
# 1584933                                                          Frigia Num.132                                           FRIGIA NUM 132
# 725277                                       Avd. ARTEAGA Y SALAZAR, 226 Casa 1                              AVENIDA ARTEAGA SALAZAR 226
# 601817                                                     Retorno 46 24 Avante                                     RETORNO 46 24 AVANTE
# 792888                                           AV ALVARO OBREGON 298 DEPTO 10                               AVENIDA ALVARO OBREGON 298
# 1275575                                              Ave Juan Alvarez Lt 1 Mz 1                                         AVE JUAN ALVAREZ
# 483783                                               Cl. SEVILLA, 510 Dpto. 103                                        CALLE SEVILLA 510
# 2283888                              Xochimilco Tulyehualco 39 Mz 6 Depto C 301                                XOCHIMILCO TULYEHUALCO 39
# 1223522                                                    Oriente 8 Lt 8 Mz 60                                                ORIENTE 8
# 1359633                                           2 Cda San Andres Tetepilco 11                            2 CDA SAN ANDRES TETEPILCO 11
# 1657799                        Jose Lopez Portillo 3 Edif. a Tripoli Depto. 101                                    JOSE LOPEZ PORTILLO 3
# 245059                                            Centenario 407 Cjon de Est 24                            CENTENARIO 407 CJON DE EST 24
# 444753                              DR. JOSE MARIA VERTIZ NUM. 993 DEPTO. B 202                             DR JOSE MARIA VERTIZ NUM 993
# 1424191        Cl. UNIVERSIDAD, 220 And. U H LAS AMERICAS, Edif. D-9, Dpto. 002                   CALLE UNIVERSIDAD 220 AND LAS AMERICAS
# 1948429                                                     Av.tlahuac Num.6985                                 AVENIDA TLAHUAC NUM 6985
# 2122220                                                             Platino 351                                              PLATINO 351
# 534740                                                          Amatl Num 182-A                                            AMATL NUM 182
# 188915                                   San Pablo Xalpa 434 Edif 4 B Depto 403                                      SAN PABLO XALPA 434
# 359525                                                             Poussin 16 3                                             POUSSIN 16 3
# 1776862                             Calzada Legaria Num 410 Edificio 36 Depto M                                  CALZADA LEGARIA NUM 410
# 557319                                               Cerro de San Francisco 234                               CERRO DE SAN FRANCISCO 234
# 1846693                                                  Schiller 256 Depto.303                                             SCHILLER 256
# 1046476                                             Calz Vallejo 1307 Estac 123                                     CALZADA VALLEJO 1307
# 2027016                                                      COLMENAR 42 CASA 2                                              COLMENAR 42
# 1132974                                            San Sebastian de Aparicio 90                             SAN SEBASTIAN DE APARICIO 90
# 2154768                          Cl. CUITLAHUAC, 116 Edif. 4 CONDO B, Dpto. 203                                     CALLE CUITLAHUAC 116
# 2122658                                                            Inguaran 130                                             INGUARAN 130
# 456778                                 Eje 6 SUR INDEPENDENCIA, 173 Dpto. A 305                                                    EJE 6
# 117318                                                      Francia 131 Casa 11                                              FRANCIA 131
# 1026105                                                      Emiliano Zapata 19                                       EMILIANO ZAPATA 19
# 298727                                     Pestalozzi 27 Edif C Parques Dto 201                                            PESTALOZZI 27
# 1326691                                                              Lt 22 Mz 3
# 389561                                                Romero de Terreros 10 Cda                                ROMERO DE TERREROS 10 CDA
# 20962                                              BERNARDO QUINTANA 595 LT 7-A                                    BERNARDO QUINTANA 595
# 1941642                                                         Av Tlahuac 3351                                     AVENIDA TLAHUAC 3351
# 354927                                                              Pilares 211                                              PILARES 211
# 1689810                                  Cl. ACAHUATL, 77 Edif. KILIVA, Dpto. 2                                        CALLE ACAHUATL 77
# 1350464                            Pie de la Cuesta 329 Depto 301 Edif Vallarta                                     PIE DE LA CUESTA 329
# 1708137                      Camino a Santa Teresa 890 Torre 9 Depto 204 Heroes                                  CAMINO SANTA TERESA 890
# 2062021                                                       Algodonales 24 42                                        ALGODONALES 24 42
# 958561                                                                 Taxco 19                                                 TAXCO 19
# 1428303                                         Cl. AGRICULTORES, 155 Dpto. 9-A                                   CALLE AGRICULTORES 155
# 686097                                                        CDA DE MAGNOLIA 4                                               MAGNOLIA 4
# 1572972                                     Gral.a.bustamante # 156 E.h-1 D.304                              GRAL BUSTAMANTE # 156 1 304
# 633663                                              San Samuel Z 1 Mz 572 Lt 17                                             SAN SAMUEL 1
# 1465413          EJE 5 SUR MARCELINO BUENDIA, S/N Edif. A, Sec. 15-A, Dpto. 102                                                    EJE 5
# 613222                                            Cl. CUAUHTEMOC, 106 Estac. 43                                     CALLE CUAUHTEMOC 106
# 561515                                     MA. DE QUEVEDO N. 785  Oficina MOD34                    MA DE QUEVEDO NORTE 785 OFICINA MOD34
# 1790445                                LAGO ZIRAHUEN Num. 66 Departamento F 204                    LAGO ZIRAHUEN NUM 66 DEPARTAMENTO 204
# 1073528                                                  Ramiriqui 1001 Depto 2                                           RAMIRIQUI 1001
# 1936230                                                  CABALLO DE MAR  NO. 50                                     CABALLO DE MAR NO 50
# 1847104                                                  SCHILLER 303 DEPTO.-10                                             SCHILLER 303
# 2150154                      1er. Callejon de San Nicolas 15 Ed. C-1 Depto. 202                      1ER CALLEJON DE SAN NICOLAS 15 ED 1
# 573902                        Real de los Reyes 158 Edif a Depto a 201 Coyoacan                                    REAL DE LOS REYES 158
# 182842                         Mercaderes Edif Angel Ma Garibay Ent B Depto 004                                               MERCADERES
# 1628220                                                Cda Jumay Lt 45 Mz 280-a                                                CDA JUMAY
# 2070983                                                     Hda de Jilotepec 58                                      HDA DE JILOTEPEC 58
# 398185                                              Casa Grandes No. 60 Depto 6
# 673141          22 ANDADOR HACIENDA SANTO TOMAS, 55 And. 3, Edif. 55, Dpto. 201                 22 ANDADOR HACIENDA SANTO TOMAS 55 AND 3
# 1244185                                         Calle Tres No.88 Edif-d Depto-5                                         CALLE TRES NO 88
# 412587                                        Av Universidad Sn Edif 30 Depto B                                   AVENIDA UNIVERSIDAD SN
# 576933                              Calz de Tlalpan Esq Ave 3 Edif 2 B Depto 32                             CALZADA DE TLALPAN ESQ AVE 3
# 1537879                          C. Viejo a los Reyes # 20 Edif. K-1 Depto. 103                                   C VIEJO LOS REYES # 20
# 1691231                                                           Gral Anaya 37                                            GRAL ANAYA 37
# 2138632                                                         Rotograbados 44                                          ROTOGRABADOS 44
# 802873                                                         Tuxpan 18 Estc 5                                         TUXPAN 18 ESTC 5
# 2177187                                                              Damasco 52                                               DAMASCO 52
# 1584026                                                            Lusitania 30                                             LUSITANIA 30
# 2240198                                             1 CDA CUAUHTEMOC, 4 Casa 13                                       1 CDA CUAUHTEMOC 4
# 579700                                                         Calle H 16 Mz Ii                                                 CALLE 16
# 2258937                                           Cda. CALLE 7, S/N PREDIO INT.                                              CDA CALLE 7
# 529630                           Ed Mexico en I Dep 1004 u H Integracion Latino                 ED MEXICO EN DEP 1004 INTEGRACION LATINO
# 2049781                                                     Nevado de Toluca 20                                      NEVADO DE TOLUCA 20
# 1730244                                              CA ITO 25 COND.4 DEPTO.F-4                                                CA ITO 25
# 2220232                                                Contraloria 67 Depto 106                                           CONTRALORIA 67
# 352420                                                   Baltimore 103 Cjon.  7                                     BALTIMORE 103 CJON 7
# 1811024                                       TONANTZIN 30 EDIFICIO B DEPTO 101                                             TONANTZIN 30
# 2211203                                            Almeja Lt 6 Mz 30 Dpto.  201                                                   ALMEJA
# 441044                                                          Universidad 443                                          UNIVERSIDAD 443
# 141603                                      Cl. FRANCISCO I MADERO, MZ-33 LT-35                                   CALLE FRANCISCO MADERO
# 502539                                            Emiliano Zapata 89 Depto. 102                                       EMILIANO ZAPATA 89
# 2006194                      Avd. INSURGENTES SUR, 3493 Edif. 11 GEA, Dpto. 901                             AVENIDA INSURGENTES SUR 3493
# 758782                                               Cl. SABINO, 298 Local c. 1                                 CALLE SABINO 298 LOCAL 1
# 445671                                Cl. 5 DE FEBRERO, 1058 Edif. B, Dpto. 605                                  CALLE 5 DE FEBRERO 1058
# 1548364                                                    Cda 5 de Mayo 3 Prov                                              MAYO 3 PROV
# 1351510                                     2do CJON PORTO ALEGRE LT 12 MZ 10 B                                    2DO CJON PORTO ALEGRE
# 503920                                                Republicas 44 Miravalle 0                                REPUBLICAS 44 MIRAVALLE 0
# 1135279                                     Cl. EMILIANO ZAPATA, 4137 Dpto. D-4                               CALLE EMILIANO ZAPATA 4137
# 1781510                                          MARIANO ESCOBEDO 133 DEPTO-706                                     MARIANO ESCOBEDO 133
# 1320618                 Cl. HENEQUEN, S/N Edif. 68, Sec. ZONA VERDE, Local c. 3                                     CALLE HENEQUEN NORTE
# 651279                                        Rinc Colonial Edif Lima Depto 404                                            RINC COLONIAL
# 682887                             Cl. CONSTITUYENTE C ECHANOVE, 136 Dpto. 1203                         CALLE CONSTITUYENTE ECHANOVE 136
# 70828                              Cl. TOLTECAS, 166 Edif. TORRE K2, Dpto. 1017                                       CALLE TOLTECAS 166
# 1307119                                Cordillera Edif 50 Depto 302 Zona Morada                                               CORDILLERA
# 1972173                                                           U Guerrero 36                                            U GUERRERO 36
# 1174986                                         Estado de Tamaulipas Lt 29 Mz 3                                     ESTADO DE TAMAULIPAS
# 2036580                        Insurgentes Sur 4411 Edif 27 Depto 202 Tlalpan 0                                     INSURGENTES SUR 4411
# 1990132                                                       Izamal M-134 L-22                                            IZAMAL 134 22
# 940538                                       SAN LUIS POTOSÍ N. 172  Depto. 401                                SAN LUIS POTOSÍ NORTE 172
# 2258685                                              Prol 5 de Mayo Mz 14 Lt 16                                           PROL 5 DE MAYO
# 9612                                             Cda. Vasco de Quiroga L-2016-B                                CDA VASCO DE QUIROGA 2016
# 752319                     Cl. MELLADO, 51 Edif. C Subcondominio 2, Dpto. C-310                                         CALLE MELLADO 51
# 2069737                                                                 Dione 7                                                  DIONE 7
# 1016585                           Crta. TENAYUCA CHALMITA, 50 Edif. 68, Dpto. 3                                CRTA TENAYUCA CHALMITA 50
# 403921                                     Calz Santa Anita 37 Cond 4 Local 307                                   CALZADA SANTA ANITA 37
# 1047666                               Calz Vallejo 1307 Mz Vii Edif J Depto 302                                     CALZADA VALLEJO 1307
# 1243691                                 AVENIDA NORTE N. 169 E Departamento 202                 AVENIDA NORTE NORTE 169 DEPARTAMENTO 202
# 373130                                             San Francisco 1739 Depto 402                                       SAN FRANCISCO 1739
# 868639                                          Rep. de Argentina 69 Depto. D-5                                      REP DE ARGENTINA 69
# 1814493                                               Mexico Tacuba 92 Depto 24                                         MEXICO TACUBA 92
# 1609719                                                 EL ROSARIO MZ.241 LT.22                                               EL ROSARIO
# 54016                                       Av.Central 175 T.Hamburgo Depto.602                             AVENIDA CENTRAL 175 HAMBURGO
# 1443818                                             Domingo Arellano Ramirez 86                              DOMINGO ARELLANO RAMIREZ 86
# 1522304                                     RODODENDRO, 19 Edif. A-1, Dpto. 301                                            RODODENDRO 19
# 1304595                                                Oriente 259 No.228 Int.3                                 ORIENTE 259 NO 228 INT 3
# 827199                                             Cda de Rivero 40 Depto a 201                                                RIVERO 40
# 416832                            Toledo 89 Edif a Depto 4 Estac Cto Serv Jaula                                                TOLEDO 89
# 988184                                        Lucio Blanco 8-C Mz 12 Lt 15 Z 13                                           LUCIO BLANCO 8
# 1738226                                                             Legaria 169                                              LEGARIA 169
# 2224407                                                       Genaro Garcia 312                                        GENARO GARCIA 312
# 596963                                                   Cl. COAPAN, M-40 LT-10                                          CALLE COAPAN 40
# 1862571                                           ARQUIMEDES NUM. 25 DEPTO. 401                                        ARQUIMEDES NUM 25
# 571747                               Cda. 2DA PROL MELCHOR OCAMPO, 20 LOTE 50 A                         A PROL MELCHOR OCAMPO 20 LOTE 50
# 1779365                                                            Lago Naur 78                                             LAGO NAUR 78
# 1281635                                                              Canela 260                                               CANELA 260
# 1276685                                         Jose Ma del Castillo Mz 7 Lt 26                                     JOSE MA DEL CASTILLO
# 1592453                                                 Cl. ALHELI, MZ-56 LT-19                                             CALLE ALHELI
# 334711                                        Av Col. Del Valle 621 Depto A-102                                                  AVENIDA
# 625342                                                 Cl. TALLO, 2 Dpto. 403-C                                            CALLE TALLO 2
# 2133947                                     Imprenta Num 249 Edif B Depto A-301                                         IMPRENTA NUM 249
# 1063185                                                     Fernando Amilpa 171                                      FERNANDO AMILPA 171
# 469967                                                 Bulgaria 130 C Depto 401                                             BULGARIA 130
# 1393801                                                     Cl. ING CIVILES, 16                                     CALLE ING CIVILES 16
# 1141278                                                  Lopez De Santa Ana 280                                   LOPEZ DE SANTA ANA 280
# 659497                          1ER RETORNO CATALINA BUENDIA, 2757 Casa LT-137A                        1ER RETORNO CATALINA BUENDIA 2757
# 516155                                                      Hidalgo 24 Depto 20                                               HIDALGO 24
# 471596                                          Cl. BENITO JUAREZ, 36 Dpto. 213                                   CALLE BENITO JUAREZ 36
# 32289                                                  Cl. MAGNOLIA, 21 Dpto. 5                                        CALLE MAGNOLIA 21
# 675823                                                       Hda Sta Cecilia 95                                       HDA STA CECILIA 95
# 1372363                                                           Sur 119 a 211                                              SUR 119 211
# 5687                                                         Paso de la Laja 58                                       PASO DE LA LAJA 58
# 1252212                                           Cl. UNO, 31 Edif. F, Dpto. 13                                             CALLE UNO 31
# 1103121                                          CALLE NORTE 12 4439 DEPTO B302                                      CALLE NORTE 12 4439
# 2207235                                                          Oriente 166 36                                           ORIENTE 166 36
# 397135                                                Dr. Barragan 520 Depto. 9                                          DR BARRAGAN 520
# 1680058                                                         ZEUZ MZ 9 LT 30                                                     ZEUZ
# 1294863                                                            Sur 171 2103                                             SUR 171 2103
# 2144138                                               SANTA ESCUELA 82 LOCAL 58                                SANTA ESCUELA 82 LOCAL 58
# 354279                                                  AMORES N. 1233  Casa 12                                        AMORES NORTE 1233
# 2007120                                   Insurgentes Sur 3579 Torre 2 Ofna 808                                     INSURGENTES SUR 3579
# 1767678                                   Cl. BOSQUE DE CIRUELOS, 130 Estac. 64                             CALLE BOSQUE DE CIRUELOS 130
# 1343980                                                        Gavia Mz 50 Lt 4                                                    GAVIA
# 891356                                                     Hamburgo 15 Local-1b                                     HAMBURGO 15 LOCAL 1B
# 880481                                                     Bolivar 8 Depto. 110                                                BOLIVAR 8
# 1201936                                             Villa Motolinia Lt 48 Mz 23                                          VILLA MOTOLINIA
# 302308                                              OBRERO MUNDIAL 851 DEPTO. C                                       OBRERO MUNDIAL 851
# 1107166                                                            Granito 6220                                             GRANITO 6220
# 683119                                  AV CARLOS ECHANOVE 136 TORRE DEPTO 1202                              AVENIDA CARLOS ECHANOVE 136
# 1939584                          Cl. LAS BODAS DE FIGARO, 82 Edif. 6, Dpto. 103                             CALLE LAS BODAS DE FIGARO 82
# 461636                                                       Luisa 187 Estac 12                                                LUISA 187
# 1010144                                Cl. ANTONIO ROANOVA VARGAS, MZ-55-A LT-4                             CALLE ANTONIO ROANOVA VARGAS
# 1804937                              CALZ GRAL MARIANO ESCOBEDO 193  DEPTO  606                        CALZADA GRAL MARIANO ESCOBEDO 193
# 898630                                        Republica de Uruguay 75 Local 113                        REPUBLICA DE URUGUAY 75 LOCAL 113
# 1565926                                       AV 11 402 COND 4 EDIF C DEPTO 201                                           AVENIDA 11 402
# 1168264                           CALZ SAN JUAN DE ARAGON 530 T LIRIO DEPTO 406                     CALZADA SAN JUAN DE ARAGON 530 LIRIO
# 1264265                                              Andres Molina Enriquez 206                               ANDRES MOLINA ENRIQUEZ 206
# 1553850                                                       Ed 102 Mz 1 Dep C                                                   ED 102
# 528440                            Eje 10 SUR AV COPILCO, 300 Edif. 9, Dpto. 301                                                   EJE 10
# 456572                                                 Bolivar 1161 Depto a 404                                             BOLIVAR 1161
# 1279296                                                     Playa Tecolutla 494                                      PLAYA TECOLUTLA 494
# 198112                                                       Tierra Colorada 25                                       TIERRA COLORADA 25
# 839456                                                    Heroes 68 Depto B-102                                                HEROES 68
# 261067                                                            Heliopolis 56                                            HELIOPOLIS 56
# 1553841                                                       Ed 106 Dep D Mz 1                                               ED 106 DEP
# 357455                                                       Giotto 51 Depto 12                                                GIOTTO 51
# 2226036                                                          Calle 11 No 91                                           CALLE 11 NO 91
# 1872880                                           General Quintana 31 Int A-103                              GENERAL QUINTANA 31 INT 103
# 843948                                                    Libertad 54 Depto. 13                                              LIBERTAD 54
# 1022886                      Andador 26 18 Ent D Depto 308 Acueducto de Guadalu                                            ANDADOR 26 18
# 920432                                          CLAVIJERO 16 ESTACIONAMIENTO 23                          CLAVIJERO 16 ESTACIONAMIENTO 23
# 1814672               Calz. MEXICO TACUBA, 94 Edif. SUBCONDOMINIO 2, Dpto. 0704                                 CALZADA MEXICO TACUBA 94
# 525108                                 Ed B 17 Dep 1003 u H Copilco Universidad                       ED 17 DEP 1003 COPILCO UNIVERSIDAD
# 447647                         EJE 5 SUR RAMOS MILLAN, 105 Edif. 1, Dpto. A 201                                                    EJE 5
# 2000510                                         Robles Esq. Cedros Mz.241 Lt.11                                        ROBLES ESQ CEDROS
# 413931                                              Cl. ZEMPOALA, 242 Dpto. PB2                                       CALLE ZEMPOALA 242
# 2229658                                Alberto Branif 11 y 15 Edif. B Depto.401                                     ALBERTO BRANIF 11 15
# 207471                           Anillo Periferico Sup Mz 4 Edif H 21 Depto 102                                    ANILLO PERIFERICO SUP
# 1165543                        S J DE ARAGON 439 RNDA GUADALUPE CON C DEP B 403               S DE ARAGON 439 RNDA GUADALUPE CON DEP 403
# 1704030                                                  Cl. YAUTLA, MZ-16 L-30                                             CALLE YAUTLA
# 152911                                        Avd. EMILIANO ZAPATA, MZ-81 LT-12                                  AVENIDA EMILIANO ZAPATA
# 1833099                                BAHIA DE PERULA Num. 80 Departamento 903                  BAHIA DE PERULA NUM 80 DEPARTAMENTO 903
# 906640                                                                 Flora 18                                                 FLORA 18
# 1042672                                      Pais Lt 6 Mz 6 Santa Maria Ticoman                                                     PAIS
# 1367578                  Cl. TENIENTE PILOTO AVIADOR JAVIER MARTINEZ VALLE, 438  CALLE TENIENTE PILOTO AVIADOR JAVIER MARTINEZ VALLE 438
# 1506781                      Jose Barragan Hernandez Calle 2 Lt 45 Mz 17 Sup Mz                          JOSE BARRAGAN HERNANDEZ CALLE 2
# 615302                                                  Marino Mosco Sanchez 31                                  MARINO MOSCO SANCHEZ 31
# 286534                                   Avd. JARDIN, 257 Edif. 5-2, Dpto. 1907                                       AVENIDA JARDIN 257
# 412779                                 Cumbres de Acultzingo Sn Edif 14 Depto B                                 CUMBRES DE ACULTZINGO SN
# 574727                                                       Cda. PACIFICO, 366                                         CDA PACIFICO 366
# 2203341                                                           XANAGUIA L-20                                              XANAGUIA 20
# 1897845                                        JOSE MARTI NUM. 252 DEPTO. B 403                                       JOSE MARTI NUM 252
# 1348438                                Cda. de Historiadores No. 8 Depto. I-201                                       HISTORIADORES NO 8
# 1493843                           Av Fuerte de Loreto 427 Mz C Edif B Depto 001                             AVENIDA FUERTE DE LORETO 427
# 1465944                                  Calle S/nombre Frente Vii o Edif.e.301                                  CALLE NOMBRE FRENTE VII
# 1506852                      Carlos Mancilla Calle 3 Lt 33 Mz 20 Sup Mz 6 Unida                                  CARLOS MANCILLA CALLE 3
# 1372842                                                           Sur 113 a 225                                              SUR 113 225
# ...
# 1709616                                        Cda Flor de Roca Mz 299-a Lt 1-d                                         CDA FLOR DE ROCA
# 909534                                                 Cl. CORDOBA, 42 Ofi. 802                                 CALLE CORDOBA 42 OFI 802
# 1993431                                                        Tekax 256 Casa 9                                                TEKAX 256
# 1516789                                                        Xochipilli  Lt-3                                               XOCHIPILLI
# 2294581                                                  San José Mza. 5 Lote 2                                    SAN JOSÉ MZA 5 LOTE 2
# 2141209                                               Emiliano Zapata 143 E-102                                  EMILIANO ZAPATA 143 102
# 1365193                                                  Oriente 160 Ret 303 11                                   ORIENTE 160 RET 303 11
# 1214991                                                             Av 604 B 52                                           AVENIDA 604 52
# 360048                                                Augusto Rodin 442 Depto 6                                        AUGUSTO RODIN 442
# 2111657                                                          TERRAZAS     3                                               TERRAZAS 3
# 1438474                                              Corl. Lino Merino Num. 171                                 CORL LINO MERINO NUM 171
# 1828334            Cl. LAGO ALBERTO, 300 Edif. TORRE 3B, Sec. FASE 2, Dpto. 908                                   CALLE LAGO ALBERTO 300
# 863672                                                     Zarco 57 Depto B 303                                                 ZARCO 57
# 889960                                                   Cl. MILAN, 14 Ofi. 104                                   CALLE MILAN 14 OFI 104
# 2282738                                                             Pedregal 37                                              PEDREGAL 37
# 1676063                                                Cl. AZTECAS, MZ-11 LT-11                                            CALLE AZTECAS
# 1721306                                                     Mayahuel 6 Depto 15                                               MAYAHUEL 6
# 345336                                          Cl. PROVIDENCIA, 1126 Dpto. 304                                   CALLE PROVIDENCIA 1126
# 2008300                                               J J Ramirez Ocon M-2 L-15                                      J RAMIREZ OCON 2 15
# 654282                                    Cl. LAS FLORES, 72 Edif. F, Dpto. 202                                      CALLE LAS FLORES 72
# 1979525                                        COBALTO Num. 14 Departamento 3-D                            COBALTO NUM 14 DEPARTAMENTO 3
# 2272201                      CDA INS 2 E INSURGENTES 88 COL S GREGORIO ATLAPULC                                 CDA INS 2 INSURGENTES 88
# 1012169                                              Ruben Dario Lt. 2  Mz. 108                                              RUBEN DARIO
# 97661                                             1 PRIV ROSA DE BENGALA, LT-15                                   1 PRIV ROSA DE BENGALA
# 171137                                                 San Jeronimo 273 Casa 21                                         SAN JERONIMO 273
# 1485183                                                       Lt 3 Mz 21 Secc 1
# 601082                                                        Retorno 30 Num 22                                        RETORNO 30 NUM 22
# 2182109                                                Estampado 20 Depto B 101                                             ESTAMPADO 20
# 2110460                                                          Cl. OYAMEL, 16                                          CALLE OYAMEL 16
# 65942                                      Avd. CENTRAL, 471 Edif. 3, Dpto. 102                                      AVENIDA CENTRAL 471
# 525292                           Edif B 21 Depto 601 Unidad Copilco Universidad
# 30836                                             Curuco Lt 11 M Z 7 Ave Real 0                                                   CURUCO
# 148499                                                  Cjn. 29 DE OCTUBRE, S/N                                  CJN 29 DE OCTUBRE NORTE
# 829372                                              Tenochtitlan 80 Depto a 301                                          TENOCHTITLAN 80
# 804731                                                Chilpancingo 14 Depto 402                                          CHILPANCINGO 14
# 1221513                                                            Calle 631 46                                             CALLE 631 46
# 809953                                        Cl. NOGAL, 187 Edif. C, Dpto. 201                                          CALLE NOGAL 187
# 1995838                                         Tixpehual Lt 11 Mz 301 Padierna                                                TIXPEHUAL
# 1952182                                                              DEODATO 76                                               DEODATO 76
# 1329241                                       15 DE SEPTIEMBRE MZ 29 LT 26 ZN 1                                         15 DE SEPTIEMBRE
# 332927                                                  Cda Sn Borja 55 Depto 5                                          CDA SN BORJA 55
# 1584296                                                  Cine Mexicano 12 Cs.34                                   CINE MEXICANO 12 CS 34
# 623641                                                   Cuitlahuac Mz 30 Lt 52                                               CUITLAHUAC
# 1690499                                                            LAURELES L-5                                               LAURELES 5
# 1702026                                                  Avd. LUIS CABRERA, 283                                 AVENIDA LUIS CABRERA 283
# 200897                           CAMINO REAL DE SAN MARTIN 398 EDIF A DEPTO 404                            CAMINO REAL DE SAN MARTIN 398
# 452314                                        Cl. ANICETO ORTEGA, 958 Dpto. PB2                                 CALLE ANICETO ORTEGA 958
# 347712                                                  Van Dyck 77 Depto 102 B                                              VAN DYCK 77
# 76439                                            PROLONGACION ITANDEHUI NUM. 47                            PROLONGACION ITANDEHUI NUM 47
# 1744140                                                          Mar Arabigo 13                                           MAR ARABIGO 13
# 331270                                                  Louisiana 176 Depto 401                                            LOUISIANA 176
# 928488                                                DR VELASCO 56 DEPTO A-101                                            DR VELASCO 56
# 1213569                                                            Calle 591 95                                             CALLE 591 95
# 1177676                                      Norte 80 a 6556 San Pedro El Chico                         NORTE 80 6556 SAN PEDRO EL CHICO
# 2163557                                                      Bacum 37 Depto B-2                                                 BACUM 37
# 824807                        Av Paseo De La Reforma Num 250 Modulo B Depto 102               AVENIDA PASEO DE LA REFORMA NUM 250 MODULO
# 760602                         Cl. ESTRELLA, 171 Edif. K, Ent. ACC O, Dpto. 203                                       CALLE ESTRELLA 171
# 2000862                                             Piedra Tronada Mz 137 Lt 13                                           PIEDRA TRONADA
# 1322132                                             Cl. CHINANTECA, MZ-21 LT-21                                         CALLE CHINANTECA
# 451433                                                Universidad 650 Depto 302                                          UNIVERSIDAD 650
# 1892217                                            2 Cda Cjon Tiro Al Pichon 15                             2 CDA CJON TIRO AL PICHON 15
# 1302959                                    ORIENTE 249 No 217 TORRE-B DEPTO 305                                       ORIENTE 249 NO 217
# 832160                                         Cl. CEDRO, 8 Ent. CEDRO, Dpto. B                                            CALLE CEDRO 8
# 796297                                            Juan de la Barrera 20 Depto 3                                    JUAN DE LA BARRERA 20
# 1719209                                                Estanque de los Lotos 19                                 ESTANQUE DE LOS LOTOS 19
# 1381898                                                       Rio Villa Alta 10                                        RIO VILLA ALTA 10
# 1902913                                                          Chapultepec 10                                           CHAPULTEPEC 10
# 82437                                                              Norte Num.73                                             NORTE NUM 73
# 903791                                                    MARSELLA 67 DEPTO-203                                              MARSELLA 67
# 1715002                                                Prv. ALCATRAS, M-16 L-10                                       PRV ALCATRAS 16 10
# 1136613                                   Cl. ATIZAPAN DE ZARAGOZA, MZ-100 LT-8                               CALLE ATIZAPAN DE ZARAGOZA
# 1655582                                                         Pino Lt 66 Mz 4                                                     PINO
# 604584                                            Santa Ana Edif. 4-a Depto 202                                                SANTA ANA
# 1008255                                                             CAFETO L-14                                                CAFETO 14
# 1890756                                                 Bosque de Almendros 325                                  BOSQUE DE ALMENDROS 325
# 615142                                           Av de las Torres 10 Col Avante                                 AVENIDA DE LAS TORRES 10
# 149512                                              Cda. JACARANDAS, MZ-31 LT-6                                           CDA JACARANDAS
# 2186543                                                             Siberia 273                                              SIBERIA 273
# 2227716                                                           3venida 4 349                                            3VENIDA 4 349
# 1833782                                                 Tonatzin 77 Depto G 301                                              TONATZIN 77
# 2258190                                                Avd. ARCOS PONIENTE, 305                               AVENIDA ARCOS PONIENTE 305
# 1220206                                                               Av 547 62                                           AVENIDA 547 62
# 1954067                                  Abelardo Rodriguez Z 157 Mz 627 Lt 1 a                                   ABELARDO RODRIGUEZ 157
# 1542874                                         Av. Once 71 Reg. 2-b Depto. 102                                    AVENIDA ONCE 71 REG 2
# 1173823                                                    Puerto de Tuxpan 126                                     PUERTO DE TUXPAN 126
# 1609201                      Alvaro Obregon Lt 1288 Mz 130 Bo Sn a Sn L Tezonco                                           ALVARO OBREGON
# 1777447                                                 LAGO ERNE 197 DEPTO 303                                            LAGO ERNE 197
# 221716                               CALZ AZCAPOTZALCO LA VILLA 260 DEPTO B 202                        CALZADA AZCAPOTZALCO LA VILLA 260
# 1514742                                               Pajares 221 Valle del Sur                                PAJARES 221 VALLE DEL SUR
# 1978096                                Cl. FUENTE DE LA INFANCIA, 51 Cuarto. 23                 CALLE FUENTE DE LA INFANCIA 51 CUARTO 23
# 1199206                                                         Norte 82 a 5207                                            NORTE 82 5207
# 211387                                                    Campo Pozo Pedregal 7                                    CAMPO POZO PEDREGAL 7
# 1563791                                                Hidalgo 17 Edif.g Dt.203                                               HIDALGO 17
# 1620336                                                    Antonio Gutierrez 31                                     ANTONIO GUTIERREZ 31
# 1732870                                           CALZ MEX TACUBA 1595 EST 0183                         CALZADA MEX TACUBA 1595 EST 0183
# 1612620                                                             Calle 17 38                                              CALLE 17 38
# 2160176                                           Av del Taller 153 Loc Com a 0                         AVENIDA DEL TALLER 153 LOC COM 0
# 555313                                                               Canada 152                                               CANADA 152
# 437874                                                       Amores 935 Depto.1                                               AMORES 935
# 1430336                                             Cl. ALTO LUCERO, MZ-1 LT-13                                        CALLE ALTO LUCERO
# 691379                                      Carr Mexico Toluca 5468 Th 4 Edif 3                             CARR MEXICO TOLUCA 5468 TH 4
# 1127247                                                   Guanajuato Lt 1 Mz 23                                               GUANAJUATO
# 271197                                       AVENIDA CUITLAHUAC 2314 Dpto.  503                                  AVENIDA CUITLAHUAC 2314
# 912327            Cl. DR RAFAEL LUCIO, 103 Edif. E-1 ESTRELLA POLAR, Estac. S/N                                CALLE DR RAFAEL LUCIO 103
# 1214320                                 CALLE 595, 63 Edif. BAHIA II, Estac. 25                                             CALLE 595 63
# 162154                                                       Calle 3 Lt 36 Mz 3                                                  CALLE 3
# 2111995                                              CAM REAL A XICALCO     285                                     CAM REAL XICALCO 285
# 1527178                                             1a CDA MORELOS, MZ-4 LT-106                                           1A CDA MORELOS
# 82537                                                                  Norte 61                                                 NORTE 61
# 1501945                                                 Sm 3 Mz 12 Agrup 44 1 0                                                     SM 3
# 1992398                                                        Tinum 125 Casa 6                                                TINUM 125
# 1981381                               Anillo Periferico 4091 Edificio M5 Dpto 8                                   ANILLO PERIFERICO 4091
# 1304288                                                 Oriente 259 216 Depto 4                                          ORIENTE 259 216
# 1302321                                                              Sur 20 540                                               SUR 20 540
# 1101222                                                              Godard 105                                               GODARD 105
# 1127994                                                      Tixtla Lt 1 Mz 118                                                   TIXTLA

# %% [markdown]
# OUTPUT        ORIGINAL        WANTED OUTPUT
# CL. SUR 128     Cl. SUR 128, 12       SUR 128
# SUR 126 A.       Sur 126 a 9      SUR 126
# SUR 126-A NUM.      Sur 126-a Num.17      SUR 126
# CL. SUR 128, 22 CASA      Cl. SUR 128, 22 Casa 4    SUR 128
# CL. SUR 128, 22 DPTO.     Cl. SUR 128, 22 Dpto. 1   SUR 128
# SUR         SUR 122 S/N     SUR 122
# SUR 122 ESQ PONIENTE        Sur 122 Esq Poniente 83     SUR 122
# SUR 112 A 23 DEPTO        Sur 112 a 23 Depto 12        SUR 112
# SUR 120 A-6 DEPTO       Sur 120 A-6 Depto 302-C       SUR 120
# CL. SUR 124, 3 DPTO.          Cl. SUR 124, 3 Dpto. 3        SUR 124
# SUR 114 NUM. 46  DEPTO.       SUR 114 N. 46  Depto. 303      SUR 114
#
# Sostenes Rocha 18                                    ROCHA 18       SOSTENES ROCHA 18
# Gral. Felix u Gomez 95                                    GOMEZ 95      GRAL FELIX U GOMEZ 95
# Sostenes Rocha Gral 10                                     GRAL 10      SOSTENES ROCHA GRAL
# Cda. 3 de Observatorio Nu.10 Depto-302                      CDA 3       OBSERVATORIO 10
# Cl. GRAL MANUEL M PLATA, 123                             PLATA 123      GRAL MANUEL M PLATA 123
# Plata Gral 110                                    GRAL 110          PLATA GRAL 110
# Cl. CAMINO A BELEN, 85 Edif. R, Casa 223                 BELEN 85       CAMINO A BELEN 85
# Vereda del Tanque 48 Lomas de Santa Fe                 TANQUE 48        VEREDA DEL TANQUE 48
# Calle Estrella Fugas Mz.c Lt.13                       LT 13             ESTRELLA FUGAZ
# Prv. RAUL ZARATE MACHUCA, 11                          MACHUCA 11        RAUL ZARATE MACHUCA 11
#
#
#
# Cl. SUR 124, 3 Dpto. 4                   DPTO 4           SUR 124
# Cl. SUR 114 A, 21 BIS Dpto. 4            BIS DPTO 4       SUR 114
# Sur 114-a 29                             A 29             SUR 114
# AV. OBSERVATORIO  209  INT.02            INT 02           OBSERVATORIO 209
# Cl. SUR 114, 29 Dpto. 1                   DPTO 1          SUR 114
# Sur 114 a 22                            A 22              SUR 114
# Sur 116 34 Dpto.  4                      DPTO 4           SUR 114
# Sur 114 a 43 Dpto.  301                     DPTO 301      SUR 114
# Avd. OBSERVATORIO, 151 Dpto. 01-A           DPTO 01-A     OBSERVATORIO 151
#
#
#
#
# Cda. 3 de Obesrvatorio Num.10 Depto-201                                          CDA 3    Cda. 3 de Obesrvatorio 10
# Cda. 4A CDA OBSERVATORIO, 29                       CDA 4    Cda. 4A CDA OBSERVATORIO 29
# Eje 3 PONIENTE AMORES, 33 Dpto.S202                                               EJE 3    EJE 3 33
# Eje 3 Nte San Isidro 368 Edif D Depto 204                                                EJE 3    EJE 368
# OTE 259 No 108 ED 5 TURQUESA DEPTO 011                                                OTE 259    OTE 259 108
# COYOACAN EJE 3 PTE N. 33  Depto. 403                                         COYOACAN EJE 3      EJE 3 33
# Calle 17 a Mz 3 a Lt 01                           A MZ 3     CALLE 17
# EJE 2 OTE CALZADA DE LA VIGA, 996 Casa A-5                                                  EJE 2    EJE 2 996
# Eje 1 PONIENTE CALZ VALLEJO, 1268 COND 3 EDIF H13 DEPTO 403                                             EJE 1     EJE 1 1268
# Calle 11 Num 121 Casa 18                    NUM 121       CALLE 11 121
# Calle 2 42 Estac 45                          ESTAC 45     CALLE 2 42
# Calle 29 Num 51 Depto a 201               NUM 51           CALLE 29 51
# Calle 13 170                              13 170           CALLE 13 170
# Calle 631 Num. 17                        NUM 17            CALLE 631
# Norte 178 566                         NORTE 178            NORTE 178 566
# Sur 16 233                                SUR 16           SUR 16 233
# Eje 1 OTE FC HIDALGO, 32 Edif. B2, Dpto. B-111                                 EJE 1         EJE 1 32
# Calle 4 Num 222 Depto 102 Edif B                                           NUM 222            CALLE 4 222
# Calle 327 708                          327 708       CALLE 327 708
# Norte 1-j Num 4909                     NORTE 1        NORTE 1 4909
# Eje 8 SUR AV POPOCATEPETL, 510 Edif. D, Dpto. 202                                    EJE 8      EJE 8 510
# Eje 1 NORTE JOSE ANTONIO ALZATE, 165 Y 169 Estac. 5                                       EJE 1       EJE 1 165
# Oriente 247 a No 192 Edif 02 Depto 103                                       ORIENTE 247            ORIENTE 247 192
# Tasque@a 110                    A 110           TASQUE@A 110
# Ruise@or 62                     OR 62           RUISE@OR 62
# Av Canal De Tezontle S/N Cond 2 Edif C Depto 204                               NUM COND 2       CANAL DE TEZONTLE
# Pe#oles Num. 47 Edif. a Depto. 502          OLES NUM 47       PE#OLES 47
# Norte 66 Num 3740 Depto B 101               NORTE 66         NORTE 66 3740
# AV 11 402 COND I EDIF A DEPTO 404          AV 11            AV 11 402
# Av 699 110 Agrup D Casa 8                 AV 699             AV 699 110
# Coru#a 235 Depto. 103                     A 235               CORU#A 235
# Av 565 32                               AV 565               AV 565 32
# Av 11 Num 62 Conj. 13 Casa 36             AV 11               AV 11 62
# Tasque@a 1818 Grupo D Casa 74 Paseos de
# Tasque@a                                   A 1818       TASQUE@A 1818
#
#
#
#  Isabel La Catolica 134 Edif C Depto 03      ISABEL LA CATOLICA 134 C 03      ISABEL LA CATOLICA 134
#  Cl. DR NAVARRO, 60 Edif. A, Ent. M-2, Dpto. 303    CALLE DR NAVARRO 60 A ENT M 2 DPTO 303    CALLE DR NAVARRO 60
# Rancho San Lorenzo 81 Depto 302 a      RANCHO SAN LORENZO 81 302 A          RANCHO SAN LORENZO 81
#  Cl. DR JOSE MARIA VERTIZ, 101 DEPTO.407      CALLE DR JOSE MARIA VERTIZ 101 407      CALLE DR JOSE MARIA VERTIZ 101
#  IGNACIO ALDAMA, 188 Sec. MZ-5, CASA 28         IGNACIO ALDAMA 188 SEC MZ 5 28        IGNACIO ALDAMA 188
#  JUAREZ 63 CASA 9                              JUAREZ 63 9              JUAREZ 63
#  Calle 21 22 Depto. 1                         CALLE 21 22 1             CALLE 21 22
# Av 11 Num 62 Conj. 19 Casa 44              AV 11 62 19 44               AV 11 62
# Cipres 380 Edif. G Depto. 205              CIPRES 380 G 205             CIPRES 380
#
#
#
#
#
# Isabel La Catolica 134 Edif C Depto 03                    ISABEL LA CATOLICA 134 C 03         ISABEL LA CATOLICA 134
# Cl. DR NAVARRO, 60 Edif. A, Ent. M-2, Dpto. 303           CALLE DOCTOR NAVARRO 60 A M 2 DPTO 303      CALLE DOCTOR NAVARRO 60
# Cl. LA MORENA, 425 Dpto. 401                              CALLE LA MORENA 425 DPTO 401          CALLE LA MORENA 425
# Av. Tamaulipas 1279 Edif 8 Depto 002                       AV TAMAULIPAS 1279 002             AV TAMAULIPAS 1279
# Nueva York 33 Depto B 306                                  NUEVA YORK 33 B 306                NUEVA YORK 33
# esus Carranza 21 e 108                                    JESUS CARRANZA 21 E 108             JESUS CARRANZA 21
# Miguel Laurent 1710 Dpto.  202                            MIGUEL LAURENT 1710 DPTO 202         MIGUEL LAURENT 1710
# Cl. TECNICOS Y MANUALES, 200 Edif. 15, Dpto. 401         CALLE TECNICOS Y MANUALES 200 DPTO 401       CALLE TECNICOS Y MANUALES 200
#
#
#
#
# CALLE 2, 270 Edif. B, Dpto. 501                       CALLE 2 DPTO 501                    CALLE 2 270
# Agua Caliente 129 Edif 2 Depto 501                     AGUA CALIENTE 129 501              AGUA CALIENTE 129
# Cl. LAGO GUIJA, 72 Dpto. 710                           CALLE LAGO GUIJA 72 DPTO 710       CALLE LAGO GUIJA 72
#  Cl. SIERRA GORDA, 23 CONJ ENCINOS TORRE G D 10        CALLE SIERRA GORDA 23 ENCINOS TORRE G D 10         CALLE SIERRA GORDA 23
# IGNACIO ALDAMA, 188 Sec. MZ-5, CASA 28                 IGNACIO ALDAMA 188 28                IGNACIO ALDAMA 188
# Calle 602 184                                          CALLE 602                          CALLE 602 184
# Calle 2 Num 188 Estac 64                               CALLE 2 64                         CALLE 2 188
# ALZADA VALLEJO 1307 EST.35                             CALZADA VALLEJO 1307 EST 35         CALZADA VALLEJO 1307
# Cl. TENOCHTITLAN, 100 Edif. D-10, Dpto. 302            CALLE TENOCHTITLAN 100 DPTO 302       CALLE TENOCHTITLAN 100
# Paseo de la Hacienda 79 Depto 401 Paseo de Taxque       PASEO DE LA HACIENDA 79 PASEO DE TAXQUE       PASEO DE LA HACIENDA 79
# Calle 21 22 Depto. 1                                    CALLE 21 1                        CALLE 21 22
# MONROVIA 806 DEPTO GH 04                                MONROVIA 806 GH 04                MONROVIA 806
# Calle 26 118                                            CALLE 26                          CALLE 26 118
# Calle 35 Num 35                                          CALLE 35                         CALLE 35 35
# MIGUEL BERNARD, 399 Edif. B, Dpto. 36                   MIGUEL BERNARD 399 DPTO 36        MIGUEL BERNARD 399
#
#
#
# Sur 121 529                                               SUR 121529          SUR 121 529
# Cl. 1 DE MAYO, 114 Dpto. B304                             CALLE 1MAYO 114B304         1 DE MAYO 114
# EJE 2 NORTE EULALIA GUZMAN, 150 Dpto. 205                 EJE 2150          EJE 2 150
# Cl. EUGENIO SUE, 19 Edif. EUGENIO SUE, Dpto. 310          DPTO 310          EUGENIO SUE 19
# Av 537 203                                                AV 537          AV 537 203
# Calz. VALLEJO, 122 Edif. TORRE A, Dpto. 102               CALZADA VALLEJO 122DPTO 102         CALZADA VALLEJO 122
# Calle 623 218                                             CALLE 623         CALLE 623 218
# Pte 106 Num 508 Col Defensores de la Rep                  PONIENTE 106508DEFENSORES DE LA REP         PONIENTE 106 508
# Pico de Pe#a Lara 53 Depto.1001                           A LARA 53         PICO DE PE#A LARA 53
# Cl. SERRANILLAS, 166-a Edif. C-6, Sec. LT-2, Dpto. 004             DPTO 004         SERRANILLAS 166
# 5 de Mayo # 61 Edif. a Depto. 304                         5MAYO # 61          5 DE MAYO 61
# Calle 699 92                                              CALLE 699         Calle 699 92
# Calz. AZCAPOTZALCO LA VILLA, 170 Edif. B, Dpto. 314               CALZADA AZCAPOTZALCO LA VILLA 170DPTO 314         CALZADA AZCAPOTZALCO LA VILLA 170
# Avenida 11 402 Edif.5 Estac.27                            AVENIDA 11            AVENIDA 11 402
# Avd. MEXICO, 363 Edif. TORRE C, Dpto. C-703               C 703           AVENIDA MEXICO 363
# Villa Hermosa 79 Secc. F Mz. C Lt. 40                     C LT 40         VILLA HERMOSA 79
# Cl. 6, 106 Edif. COND 1-B EDIF 7, Dpto. 403               CALLE 6         CALLE 6 106
# Avd. RICARDO FLORES MAGON, 74 And. ALMACENES 74, Edif. 338 CHIHUAHUA, Ent. B, Dpto. 1308       DPTO 1308       RICARDO FLORES MAGON 74
# Cl. LAGO HIELMAR, 44 Edif. G, Dpto. G-703                 G 703         LAGO HIELMAR 44
# Av 11 Num 62 Conj. 14 Casa 18                             AV 11         AV 11 62
# Calle Canela 19 Ed B Dep 103                              DEP 10          CANELA 19
# Cerro del Pe@On 133                                       ON 133          Cerro del Pe@On 133
#
#
# Ignacio Comonfort 168 F-205                      IGNACIO COMONFORT 168 F 205          IGNACIO COMONFORT 168
# Avd. PACIFICO, 473 Dpto. 411                      AVENIDA PACIFICO 473 DPTO 411         AVENIDA PACIFICO 473
# Callejon de Minas 27 Casa 8                      CALLEJON DE MINAS 27 8           CALLEJON DE MINAS 27
# Dr Martinez del Rio 171 B 201                   DOCTOR MARTINEZ DEL RIO 171 B 201         DOCTOR MARTINEZ DEL RIO 171
# Heroes 224 Depto 301 B                           HEROES 224 301 B         HEROES 224
# Carril 13 Edif 30 Depto 302                      CARRIL 13 30 302         CARRIL 13
# Cl. PALMA, 204 Edif. B, Dpto. B-202              CALLE PALMA 204 B DPTO B 202         CALLE PALMA 204
# Republica de Chile 49 Depto G 103                 REPUBLICA DE CHILE 49 G 103         REPUBLICA DE CHILE 49
# Gavilan 181 Edif.4-d Depto.101                    GAVILAN 181 4 D 101           GAVILAN 181
#
#
# Eje 2 A SUR SAN LUIS POTOSI, 123                        EJE 2      EJE 2 123
# Tuxpan 48 Roma Sur                                     SUR         TUXPAN 48
# Lazaro Cardenas S/n Cda                                CD          LAZARO CARDENAS
# Eje 5 OTE JAVIER ROJO GOMEZ, 462                        EJE 5      EJE 5 462
# Division del Norte 3159 Depto C 9                      NORTE 3159     DIVISION DEL NORTE 3159
# Eje 3 PTE AV THIERS, 251 Ofi. 1101                     EJE 3       EJE 3 251
# Insurgentes Sur 1388 Ofic 604                           SUR 1388      INSURGENTES SUR 1388
# 5 DE FEBRERO 523 DEPTO. A-402                          5          5 DE FEBRERO 523
# Prolongacion 5 de Mayo 3050 Casa 407                  PROLONGACION 5      PROLONGACION 5 DE MAYO 3050
# Eje 1 PONIENTE CALZ VALLEJO, 1268 Edif. G-5, Sec. COND 2, Dpto. 102             EJE 1       EJE 1 1268
# 16 de Septiembre 31                                    16            16 DE SEPTIEMBRE 31
# 2o de Noviembre 445 Edif. e Depto. 404                 2            20 DE NOVIEMBRE 445
# Hermosillo 7 Depto 302 Roma Sur                        SUR          HERMOSILLO 7
# EJE 2 PONIENTE GABRIEL MANCERA 1542 DEPTO E 401           EJE 2     EJE 2 1542
# Eje 8 SUR AV POPOCATEPETL, 415 Dpto. D 907                 EJE 8    EJE 8 415
# EJE 1 OTE AV ANDRES MOLINA ENRIQUEZ, 1006 Estac. 36          EJE 1     EJE 1 1006
# Eje 5 SUR AV SAN ANTONIO, 7 Edif. T 3 A, Dpto. 603              EJE 5     EJE 5 7
# Insurgentes Sur 1971 Edificio Estac E2-7 2                  SUR 1971      INSURGENTES SUR 7
# Anillo Periferico Sur 4863 Hab.603                     SUR 4863 603       ANILLO PERIFERICO SUR 4863
# Anillo Periferico Sur 4863 Hab.603                     SUR 4863 603       ANILLO PERIFERICO SUR 4863
# EJE 8 SUR CALZADA ERMITA IZTAPALAPA, 945 Edif. D, Dpto. 14               EJE 8      EJE 8 945
# 10 de Diciembre 123 Magdalena Mixhuca                                    10       10 DE DICIEMBRE 123
# Eje 10 SUR PEDRO ENRIQUEZ UREÑA, 540 Dpto. A-501                    EJE 10        EJE 10 540
# EJE 1 ORIENTE FFCC HIDALGO, 1404 Edif. TRES-C, Dpto. 208            EJE 1       EJE 1 1404
# Torreon 26 Depto 301 Roma Sur                                   SUR         TORREON 26

# %%
len(df_catastral)
# Out:
# 2295465

# %%
"""# --- Aquí asume que ya tienes definida la función normalizar_calle() ---

# Diccionario de pruebas: ORIGINAL -> WANTED
pruebas = {
    "Cl. SUR 128, 12": "SUR 128",
    "Sur 126 a 9": "SUR 126",
    "Sur 126-a Num.17": "SUR 126",
    "Cl. SUR 128, 22 Casa 4": "SUR 128",
    "Cl. SUR 128, 22 Dpto. 1": "SUR 128",
    "SUR 122 S/N": "SUR 122",
    "Sur 122 Esq Poniente 83": "SUR 122",
    "Sur 112 a 23 Depto 12": "SUR 112",
    "Sur 120 A-6 Depto 302-C": "SUR 120",
    "Cl. SUR 124, 3 Dpto. 3": "SUR 124",
    "SUR 114 N. 46  Depto. 303": "SUR 114",
    "Sostenes Rocha 18": "SOSTENES ROCHA 18",
    "Gral. Felix u Gomez 95": "GRAL FELIX U GOMEZ 95",
    "Sostenes Rocha Gral 10": "SOSTENES ROCHA GRAL 10",
    "Cda. 3 de Observatorio Nu.10 Depto-302": "OBSERVATORIO 10",
    "Cl. GRAL MANUEL M PLATA, 123": "GENERAL MANUEL M PLATA 123",
    "Plata Gral 110": "PLATA GRAL 110",
    "Cl. CAMINO A BELEN, 85 Edif. R, Casa 223": "CAMINO A BELEN 85",
    "Vereda del Tanque 48 Lomas de Santa Fe": "VEREDA DEL TANQUE 48",
    "Calle Estrella Fugas Mz.c Lt.13": "ESTRELLA FUGAZ",
    "Prv. RAUL ZARATE MACHUCA, 11": "RAUL ZARATE MACHUCA 11",
    "CALLE 2, 270 Edif. B, Dpto. 501": "CALLE 2 270",
    "Agua Caliente 129 Edif 2 Depto 501": "AGUA CALIENTE 129",
    "Cl. LAGO GUIJA, 72 Dpto. 710": "CALLE LAGO GUIJA 72",
    "Cl. SIERRA GORDA, 23 CONJ ENCINOS TORRE G D 10": "CALLE SIERRA GORDA 23",
    "IGNACIO ALDAMA, 188 Sec. MZ-5, CASA 28": "IGNACIO ALDAMA 188",
    "Calle 602 184": "CALLE 602 184",
    "Calle 2 Num 188 Estac 64": "CALLE 2 188",
    "ALZADA VALLEJO 1307 EST.35": "CALZADA VALLEJO 1307",
    "Cl. TENOCHTITLAN, 100 Edif. D-10, Dpto. 302": "CALLE TENOCHTITLAN 100",
    "Paseo de la Hacienda 79 Depto 401 Paseo de Taxque": "PASEO DE LA HACIENDA 79",
    "Calle 21 22 Depto. 1": "CALLE 21 22",
    "MONROVIA 806 DEPTO GH 04": "MONROVIA 806",
    "Calle 26 118": "CALLE 26 118",
    "Calle 35 Num 35": "CALLE 35 35",
    "MIGUEL BERNARD, 399 Edif. B, Dpto. 36": "MIGUEL BERNARD 399",
    "Isabel La Catolica 134 Edif C Depto 03": "ISABEL LA CATOLICA 134",
    "Cl. DR NAVARRO, 60 Edif. A, Ent. M-2, Dpto. 303": "CALLE DOCTOR NAVARRO 60",
    "Rancho San Lorenzo 81 Depto 302 a": "RANCHO SAN LORENZO 81",
    "Cl. DR JOSE MARIA VERTIZ, 101 DEPTO.407": "CALLE DOCTOR JOSE MARIA VERTIZ 101",
}

# Validación
for original, esperado in pruebas.items():
    obtenido = normalizar_calle(original)
    if obtenido == esperado:
        print(f"✅ {original} -> {obtenido}")
    else:
        print(f"❌ {original}\n   Esperado: {esperado}\n   Obtenido: {obtenido}\n")

"""
# Out:
# ❌ Cl. SUR 128, 12
#    Esperado: SUR 128
#    Obtenido: CALLE SUR 128 12
#
# ❌ Sur 126 a 9
#    Esperado: SUR 126
#    Obtenido: SUR 126 A 9
#
# ❌ Sur 126-a Num.17
#    Esperado: SUR 126
#    Obtenido: SUR 126 A 17
#
# ❌ Cl. SUR 128, 22 Casa 4
#    Esperado: SUR 128
#    Obtenido: CALLE SUR 128 22 4
#
# ❌ Cl. SUR 128, 22 Dpto. 1
#    Esperado: SUR 128
#    Obtenido: CALLE SUR 128 22 DPTO 1
#
# ❌ SUR 122 S/N
#    Esperado: SUR 122
#    Obtenido: SUR 122 S
#
# ❌ Sur 122 Esq Poniente 83
#    Esperado: SUR 122
#    Obtenido: SUR 122 ESQ PONIENTE 83
#
# ❌ Sur 112 a 23 Depto 12
#    Esperado: SUR 112
#    Obtenido: SUR 112 A 23 12
#
# ❌ Sur 120 A-6 Depto 302-C
#    Esperado: SUR 120
#    Obtenido: SUR 120 A 6 302 C
#
# ❌ Cl. SUR 124, 3 Dpto. 3
#    Esperado: SUR 124
#    Obtenido: CALLE SUR 124 3 DPTO 3
#
# ❌ SUR 114 N. 46  Depto. 303
#    Esperado: SUR 114
#    Obtenido: SUR 114 46 303
#
# ✅ Sostenes Rocha 18 -> SOSTENES ROCHA 18
# ❌ Gral. Felix u Gomez 95
#    Esperado: GRAL FELIX U GOMEZ 95
#    Obtenido: GENERAL FELIX U GOMEZ 95
#
# ❌ Sostenes Rocha Gral 10
#    Esperado: SOSTENES ROCHA GRAL
#    Obtenido: SOSTENES ROCHA GENERAL 10
#
# ❌ Cda. 3 de Observatorio Nu.10 Depto-302
#    Esperado: OBSERVATORIO 10
#    Obtenido: CDA 3 DE OBSERVATORIO NU 10 302
#
# ❌ Cl. GRAL MANUEL M PLATA, 123
#    Esperado: GENERAL MANUEL M PLATA 123
#    Obtenido: CALLE GENERAL MANUEL M PLATA 123
#
# ❌ Plata Gral 110
#    Esperado: PLATA GRAL 110
#    Obtenido: PLATA GENERAL 110
#
# ❌ Cl. CAMINO A BELEN, 85 Edif. R, Casa 223
#    Esperado: CAMINO A BELEN 85
#    Obtenido: CALLE CAMINO A BELEN 85 R 223
#
# ❌ Vereda del Tanque 48 Lomas de Santa Fe
#    Esperado: VEREDA DEL TANQUE 48
#    Obtenido: VEREDA DEL TANQUE 48 LOMAS DE SANTA FE
#
# ❌ Calle Estrella Fugas Mz.c Lt.13
#    Esperado: ESTRELLA FUGAZ
#    Obtenido: CALLE ESTRELLA FUGAS C 13
#
# ❌ Prv. RAUL ZARATE MACHUCA, 11
#    Esperado: RAUL ZARATE MACHUCA 11
#    Obtenido: PRV RAUL ZARATE MACHUCA 11
#
# ❌ CALLE 2, 270 Edif. B, Dpto. 501
#    Esperado: CALLE 2 270
#    Obtenido: CALLE 2 270 B DPTO 501
#
# ❌ Agua Caliente 129 Edif 2 Depto 501
#    Esperado: AGUA CALIENTE 129
#    Obtenido: AGUA CALIENTE 129 2 501
#
# ❌ Cl. LAGO GUIJA, 72 Dpto. 710
#    Esperado: CALLE LAGO GUIJA 72
#    Obtenido: CALLE LAGO GUIJA 72 DPTO 710
#
# ❌ Cl. SIERRA GORDA, 23 CONJ ENCINOS TORRE G D 10
#    Esperado: CALLE SIERRA GORDA 23
#    Obtenido: CALLE SIERRA GORDA 23 ENCINOS G D 10
#
# ❌ IGNACIO ALDAMA, 188 Sec. MZ-5, CASA 28
#    Esperado: IGNACIO ALDAMA 188
#    Obtenido: IGNACIO ALDAMA 188 5 28
#
# ✅ Calle 602 184 -> CALLE 602 184
# ❌ Calle 2 Num 188 Estac 64
#    Esperado: CALLE 2 188
#    Obtenido: CALLE 2 188 64
#
# ❌ ALZADA VALLEJO 1307 EST.35
#    Esperado: CALZADA VALLEJO 1307
#    Obtenido: ALZADA VALLEJO 1307 35
#
# ❌ Cl. TENOCHTITLAN, 100 Edif. D-10, Dpto. 302
#    Esperado: CALLE TENOCHTITLAN 100
#    Obtenido: CALLE TENOCHTITLAN 100 D 10 DPTO 302
#
# ❌ Paseo de la Hacienda 79 Depto 401 Paseo de Taxque
#    Esperado: PASEO DE LA HACIENDA 79
#    Obtenido: DE LA HACIENDA 79 401 DE TAXQUE
#
# ❌ Calle 21 22 Depto. 1
#    Esperado: CALLE 21 22
#    Obtenido: CALLE 21 22 1
#
# ❌ MONROVIA 806 DEPTO GH 04
#    Esperado: MONROVIA 806
#    Obtenido: MONROVIA 806 GH 04
#
# ✅ Calle 26 118 -> CALLE 26 118
# ✅ Calle 35 Num 35 -> CALLE 35 35
# ❌ MIGUEL BERNARD, 399 Edif. B, Dpto. 36
#    Esperado: MIGUEL BERNARD 399
#    Obtenido: MIGUEL BERNARD 399 B DPTO 36
#
# ❌ Isabel La Catolica 134 Edif C Depto 03
#    Esperado: ISABEL LA CATOLICA 134
#    Obtenido: ISABEL LA CATOLICA 134 C 03
#
# ❌ Cl. DR NAVARRO, 60 Edif. A, Ent. M-2, Dpto. 303
#    Esperado: CALLE DOCTOR NAVARRO 60
#    Obtenido: CALLE DOCTOR NAVARRO 60 A M 2 DPTO 303
#
# ❌ Rancho San Lorenzo 81 Depto 302 a
#    Esperado: RANCHO SAN LORENZO 81
#    Obtenido: RANCHO SAN LORENZO 81 302 A
#
# ❌ Cl. DR JOSE MARIA VERTIZ, 101 DEPTO.407
#    Esperado: CALLE DOCTOR JOSE MARIA VERTIZ 101
#    Obtenido: CALLE DOCTOR JOSE MARIA VERTIZ 101 407

# %%
import re
import unicodedata

def _strip_accents(s: str) -> str:
    return ''.join(c for c in unicodedata.normalize("NFKD", s) if not unicodedata.combining(c))

def normalizar_calle(direccion: str) -> str:
    """
    Versión consolidada:
    - Normaliza mayúsculas y quita acentos.
    - Normaliza abreviaturas (GRAL se mantiene GRAL).
    - Elimina ruido (DEPTO, EDIF, CASA, etc.).
    - Conserva el número principal y, si existe y aparece antes de un stopword,
      conserva también el primer número exterior (ej: "SUR 128, 12" -> "SUR 128 12").
    - Elimina sufijos tipo "A", "A-6", "BIS" tras números.
    - Quita "CALLE" inicial cuando es redundante con SUR/NORTE/PONIENTE/ORIENTE/EJE.
    """
    if not isinstance(direccion, str):
        return ""

    # 1) normalizar base
    t = _strip_accents(direccion).upper()
    # conservar comas para detección de exterior number; diascard otros símbolos salvo @,#,-
    t = re.sub(r"[^\w\s@#\-,]", " ", t)   # \w incluye dígitos y letras sin acentos ya
    t = re.sub(r"\s+", " ", t).strip()

    # 2) normalizar abreviaturas (no expandir GRAL a GENERAL)
    abrevs = {
        r"\bCL\b": "CALLE",
        r"\bCL\.": "CALLE",
        r"\bAVD\b": "AVENIDA",
        r"\bAV\b": "AVENIDA",
        r"\bCALZ\b": "CALZADA",
        r"\bPTE\b": "PONIENTE",
        r"\bNTE\b": "NORTE",
        r"\bOTE\b": "ORIENTE",
        r"\bCDA\b": "CDA",
        r"\bPRV\b": "PRV",
        r"\bGRAL\b": "GRAL",
        r"\bDR\b": "DR",
        r"\bNUM\b": "",
        r"\bNO\b": "",
        r"\bN\b": "",
    }
    for pat, rep in abrevs.items():
        t = re.sub(pat, rep, t)
    t = re.sub(r"\s+", " ", t).strip()

    # 3) tokenizar (mantenemos comas como tokens para detectar exterior number)
    # separar comas como tokens
    t = t.replace(",", " , ")
    tokens = [tok for tok in t.split() if tok != ""]

    # sets
    street_types = {"CALLE","AVENIDA","CALZADA","PASEO","EJE","SUR","NORTE","ORIENTE","PONIENTE","CDA","PRV",
                    "VEREDA","RANCHO","PICO","BOULEVARD","BLVD","FERROCARRIL"}
    stopwords = {"DEPTO","DPTO","DEPARTAMENTO","CASA","EDIF","EDIFICIO","TORRE","ENT","ENTRADA","SEC","SECCION",
                 "MZ","MANZANA","LT","LOTE","COND","CONJ","CONJUNTO","GRUPO","PRIVADA","INT","INTERIOR","ESQ",
                 "ESTAC","EST","ALMACENES","ANDADOR","PISO","AGRUP","COL","COLONIA"}

    # helpers
    def is_num(tok):
        return bool(re.match(r"^\d+$", tok))
    def leading_digits(tok):
        m = re.match(r"^(\d+)", tok)
        return m.group(1) if m else None
    def is_letter_suffix(tok):   # 'A', 'BIS', 'B', 'C-6', etc.
        return bool(re.match(r"^[A-Z]{1,3}(-[A-Z0-9]+)?$", tok))

    # 4) buscar índice de tipo de vialidad (si existe)
    idx_st = None
    for i, tok in enumerate(tokens):
        if tok in street_types:
            idx_st = i
            break

    # función para construir resultado dada una posición de inicio y primer número index
    def build_from(idx_name, idx_num):
        # nombre: tokens desde idx_name hasta idx_num-1 (incluir tipo)
        name_parts = [tok for tok in tokens[idx_name:idx_num] if tok != ","]
        main_num = leading_digits(tokens[idx_num]) or tokens[idx_num]
        # limpio sufijos tipo 'A' pegados al numero (114A -> 114), o token next letter
        # (pero no tocamos números exteriores aún)
        # buscar primer número exterior después de idx_num y antes de cualquier stopword
        ext = None
        j = idx_num + 1
        while j < len(tokens):
            tok = tokens[j]
            if tok == ",":
                j += 1
                continue
            if tok in stopwords:
                break
            if is_num(tok):
                ext = tok
                break
            # si token es single letter immediately after main number (suffix) skip it
            if is_letter_suffix(tok):
                # skip (we already remove suffixes)
                j += 1
                continue
            # anything else -> stop searching for ext
            break
        # construir res
        res_parts = name_parts[:]
        # si name_parts empieza con CALLE seguido de SUR/NORTE/... y queremos eliminar CALLE redundante:
        if len(res_parts) >= 2 and res_parts[0] == "CALLE" and res_parts[1] in {"SUR","NORTE","PONIENTE","ORIENTE","EJE"}:
            res_parts = res_parts[1:]  # eliminar 'CALLE' inicial redundante
        res_parts.append(main_num)
        if ext:
            res_parts.append(ext)
        # eliminar duplicados num at the end (e.g., "... 35 35")
        if len(res_parts) >= 2 and re.fullmatch(r"\d+", res_parts[-1]) and res_parts[-1] == res_parts[-2]:
            res_parts = res_parts[:-1]
        return " ".join(res_parts)

    # 5) Si hay tipo de vialidad
    if idx_st is not None:
        # buscar primer índice numérico después de idx_st
        idx_num = None
        for k in range(idx_st+1, len(tokens)):
            tok = tokens[k]
            if is_num(tok):
                idx_num = k
                break
            # si token looks like "114-A" or "114A" treat as numeric with suffix
            ld = leading_digits(tok)
            if ld:
                idx_num = k
                break
            # otherwise continue collecting name words
        if idx_num is not None:
            # limpiar sufijo si tokens[idx_num] tiene attached letters, keep only digits
            if not is_num(tokens[idx_num]):
                d = leading_digits(tokens[idx_num])
                if d:
                    tokens[idx_num] = d
            return build_from(idx_st, idx_num)
        else:
            # no number found: return name from idx_st until a stopword
            name_end = len(tokens)
            for j in range(idx_st+1, len(tokens)):
                if tokens[j] in stopwords:
                    name_end = j; break
            res = " ".join([tok for tok in tokens[idx_st:name_end] if tok != ","])
            # eliminar "CALLE" redundante
            if res.startswith("CALLE ") and res.split()[1] in {"SUR","NORTE","PONIENTE","ORIENTE","EJE"}:
                res = " ".join(res.split()[1:])
            return res.strip()

    # 6) si no hay tipo de vialidad, fallback: tomar primer número como main, conservar possible next number
    idx_num = None
    for i, tok in enumerate(tokens):
        if is_num(tok) or leading_digits(tok):
            idx_num = i
            if not is_num(tok) and leading_digits(tok):
                tokens[i] = leading_digits(tok)
            break
    if idx_num is not None:
        # name part is tokens[:idx_num]
        # find ext number before a stopword
        ext = None
        j = idx_num + 1
        while j < len(tokens):
            if tokens[j] in stopwords:
                break
            if is_num(tokens[j]):
                ext = tokens[j]; break
            if tokens[j] == ",":
                j += 1; continue
            if is_letter_suffix(tokens[j]):
                j += 1; continue
            break
        name = " ".join([tok for tok in tokens[:idx_num] if tok != ","])
        if name == "":
            # no name, just return number (rare)
            res = tokens[idx_num] if ext is None else f"{tokens[idx_num]} {ext}"
            return res
        res = name + " " + tokens[idx_num]
        if ext:
            res = res + " " + ext
        # remove duplicate trailing numbers
        res = re.sub(r"\b(\d+)\s+\1\b", r"\1", res)
        return res.strip()

    # 7) fallback: devolver texto limpio sin comas ni multiples espacios
    res = " ".join([tok for tok in tokens if tok != ","])
    res = re.sub(r"\s+", " ", res).strip()
    return res

# %%
import unicodedata
import re
import pandas as pd

# helper: quitar acentos y normalizar espacios/mayúsculas
def strip_accents(s: str) -> str:
    if not isinstance(s, str):
        return ""
    s2 = ''.join(c for c in unicodedata.normalize('NFKD', s) if not unicodedata.combining(c))
    s2 = re.sub(r"\s+", " ", s2).strip()
    return s2.upper()

# --- Diccionario de pruebas (inserta aquí todos tus casos) ---
pruebas = {
    "Cl. SUR 128, 12": "SUR 128 12",
    "Sur 126 a 9": "SUR 126 9",
    "Sur 126-a Num.17": "SUR 126 17",
    "Cl. SUR 128, 22 Casa 4": "SUR 128 22",
    "Cl. SUR 128, 22 Dpto. 1": "SUR 128 22",
    "SUR 122 S/N": "SUR 122",
    "Sur 122 Esq Poniente 83": "SUR 122",
    "Sur 112 a 23 Depto 12": "SUR 112 23",
    "Sur 120 A-6 Depto 302-C": "SUR 120",
    "Cl. SUR 124, 3 Dpto. 3": "SUR 124 3",
    "SUR 114 N. 46  Depto. 303": "SUR 114 46",
    "Sostenes Rocha 18": "SOSTENES ROCHA 18",
    "Gral. Felix u Gomez 95": "GRAL FELIX U GOMEZ 95",
    "Sostenes Rocha Gral 10": "SOSTENES ROCHA GRAL 10",
    "Cda. 3 de Observatorio Nu.10 Depto-302": "OBSERVATORIO 10",
    "Cl. GRAL MANUEL M PLATA, 123": "CALLE GRAL MANUEL M PLATA 123",
    "Plata Gral 110": "PLATA GRAL 110",
    "Cl. CAMINO A BELEN, 85 Edif. R, Casa 223": "CALLE CAMINO A BELEN 85",
    "Vereda del Tanque 48 Lomas de Santa Fe": "VEREDA DEL TANQUE 48",
    "Calle Estrella Fugas Mz.c Lt.13": "CALLE ESTRELLA FUGAZ",
    "Prv. RAUL ZARATE MACHUCA, 11": "PRV RAUL ZARATE MACHUCA 11",
    "CALLE 2, 270 Edif. B, Dpto. 501": "CALLE 2 270",
    "Agua Caliente 129 Edif 2 Depto 501": "AGUA CALIENTE 129",
    "Cl. LAGO GUIJA, 72 Dpto. 710": "CALLE LAGO GUIJA 72",
    "Cl. SIERRA GORDA, 23 CONJ ENCINOS TORRE G D 10": "CALLE SIERRA GORDA 23",
    "IGNACIO ALDAMA, 188 Sec. MZ-5, CASA 28": "IGNACIO ALDAMA 188",
    "Calle 602 184": "CALLE 602 184",
    "Calle 2 Num 188 Estac 64": "CALLE 2 188",
    "CALZADA VALLEJO 1307 EST.35": "CALZADA VALLEJO 1307",
    "Cl. TENOCHTITLAN, 100 Edif. D-10, Dpto. 302": "CALLE TENOCHTITLAN 100",
    "Paseo de la Hacienda 79 Depto 401 Paseo de Taxque": "PASEO DE LA HACIENDA 79",
    "Calle 21 22 Depto. 1": "CALLE 21 22",
    "MONROVIA 806 DEPTO GH 04": "MONROVIA 806",
    "Calle 26 118": "CALLE 26 118",
    "MIGUEL BERNARD, 399 Edif. B, Dpto. 36": "MIGUEL BERNARD 399",
    "Isabel La Catolica 134 Edif C Depto 03": "ISABEL LA CATOLICA 134",
    "Cl. DR NAVARRO, 60 Edif. A, Ent. M-2, Dpto. 303": "CALLE DR NAVARRO 60",
    "Rancho San Lorenzo 81 Depto 302 a": "RANCHO SAN LORENZO 81",
    "Cl. DR JOSE MARIA VERTIZ, 101 DEPTO.407": "CALLE DR JOSE MARIA VERTIZ 101",
}

# ------------- Validación -------------
resultados = []
for original, esperado in pruebas.items():
    obtenido = normalizar_calle(original)              # tu función debe estar definida
    esperado_norm = strip_accents(esperado)
    obtenido_norm = strip_accents(obtenido)
    ok = (obtenido_norm == esperado_norm)
    resultados.append({
        "original": original,
        "expected": esperado,
        "obtained": obtenido,
        "ok": ok
    })

df = pd.DataFrame(resultados)
total = len(df)
ok_count = df["ok"].sum()
failed = total - ok_count
pct = ok_count/total*100

print(f"Total: {total} | OK: {ok_count} | Failed: {failed} | Acierto: {pct:.1f}%\n")

# Mostrar resultados fallidos directamente
mismatches = df[df["ok"] == False].reset_index(drop=True)
if mismatches.shape[0] == 0:
    print("✅ Todos los casos pasaron")
else:
    print("❌ Casos fallidos:\n")

    for i, row in mismatches.iterrows():
        print(f"ORIGINAL : {row['original']}")
        print(f"ESPERADO : {row['expected']}")
        print(f"OBTENIDO : {row['obtained']}\n")
# Out:
# Total: 39 | OK: 37 | Failed: 2 | Acierto: 94.9%
#
# ❌ Casos fallidos:
#
# ORIGINAL : Cda. 3 de Observatorio Nu.10 Depto-302
# ESPERADO : OBSERVATORIO 10
# OBTENIDO : CDA 3
#
# ORIGINAL : Calle Estrella Fugas Mz.c Lt.13
# ESPERADO : CALLE ESTRELLA FUGAZ
# OBTENIDO : CALLE ESTRELLA FUGAS MZ C LT 13

# %% [markdown]
# Ultima version del código

# %%
import re

def normalizar_calle(calle: str) -> str:
    if not calle:
        return ""

    # --- 1. Normalización básica ---
    txt = calle.upper()
    txt = re.sub(r"[^\w\sÁÉÍÓÚÑ#@]", " ", txt)  # elimina puntuación rara
    txt = re.sub(r"\s+", " ", txt).strip()

    # --- 2. Diccionario de abreviaturas ---
    abrevs = {
        r"\bCL\b": "CALLE",
        r"\bCLL?\b": "CALLE",
        r"\bCDA\b": "CDA",  # solo mantenemos si no hay calle clara
        r"\bPRV\.?\b": "PRV",
        r"\bAVD?\.?\b": "AVENIDA",
        r"\bAV\b": "AV",
        r"\bCALZ\.?\b": "CALZADA",
        r"\bEJE\b": "EJE",
        r"\bPTE\b": "PONIENTE",
        r"\bNTE\b": "NORTE",
        r"\bN\b": "NORTE",
        r"\bSUR\b": "SUR",
        r"\bOTE\b": "ORIENTE",
        r"\bORIENTE\b": "ORIENTE",
        r"\bGRAL\.?\b": "GRAL",
        r"\bDOCTOR\b": "DR",
    }
    for pat, repl in abrevs.items():
        txt = re.sub(pat, repl, txt)

    # --- 3. Correcciones específicas (errores OCR / humanos) ---
    correcciones = {
        "FUGAS": "FUGAZ",
    }
    for k, v in correcciones.items():
        txt = txt.replace(k, v)

    # --- 4. Normalizar fechas como nombres de calle ---
    txt = re.sub(r"\b(\d{1,2})\s*O\s*DE\s+NOVIEMBRE\b", r"20 DE NOVIEMBRE", txt)
    txt = re.sub(r"\b(\d{1,2})\s*DE\s+([A-ZÁÉÍÓÚ]+)", lambda m: m.group(0), txt)

    # --- 5. Eliminar referencias NO deseadas ---
    txt = re.sub(r"\b(EDIF\.?|EDIFICIO|DPTO\.?|DEPTO|CASA|COND\.?|CONJ\.?|ESTAC\.?|ENT\.?|TORRE|MZ\.?|LT\.?|HAB\.?)\b.*", "", txt)

    # --- 6. Truncar en colonias ---
    txt = re.sub(r"\b(COL\.?|COLONIA|FRACC\.?|FRACCIONAMIENTO|BARRIO|LOMAS|ROMA SUR|MIXHUCA|SANTA FE)\b.*", "", txt)

    # --- 7. Manejo especial de prefijos ---
    # Si hay "CDA" o "PRV" al inicio y después viene un nombre, eliminarlo
    txt = re.sub(r"^(CDA|PRV)\s+\d*\s*DE?\s*", "", txt)

    # --- 8. Números sueltos con guiones o letras ---
    txt = re.sub(r"\s+[A-Z]-?\d+\b", "", txt)  # limpia "A-6", "C-9" etc.
    txt = re.sub(r"\s+[A-Z]\b", "", txt)      # limpia letras sueltas

    # --- 9. Preservar "SUR / NORTE / ORIENTE / PONIENTE" dentro de nombre principal ---
    # Cortar solo si están después de un número
    txt = re.sub(r"(\d+)\s+(SUR|NORTE|ORIENTE|PONIENTE)\b.*", r"\1", txt)

    # --- 10. Limpieza final ---
    txt = re.sub(r"\s+", " ", txt).strip()
    return txt
