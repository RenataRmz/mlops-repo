# %%
import os

import pandas as pd
import numpy as np

import re
import unidecode

# %%
# Crear una función para extraer colonia y CP
def extraer_colonia_cp(direccion, df_cp):
    for _, row in df_cp.iterrows():
        if row['d_asenta'] in direccion:
            return row['d_asenta'], row['d_codigo']
    return None, None

# %%
# Estandarizar texto: quitar acentos, convertir a minúsculas, eliminar espacios extra y reemplazar "\n" por " "
def estandarizar_texto(texto):
    if pd.isna(texto):
        return ""
    texto = texto.replace("\n", " ")  # Reemplazar saltos de línea por espacios
    texto = texto.replace(",", "")  # Quitar comas
    return unidecode.unidecode(texto.strip().lower())

# %% [markdown]
# ### Read webscrapping data

# %%
df_web = pd.read_parquet('../../data/processed/inmuebles24_departamentos_20250927.parquet')

# %%
df_web
# Out:
#        precio_mxn  lote_m2  recamaras  baños  estacionamiento  es_amueblado  \
# 0         24000.0      100        2.0    2.0              1.0             0
# 1         12000.0       50        1.0    1.0              1.0             1
# 2         34100.0      232        3.0    4.0              2.0             0
# 3         16000.0      165        2.0    1.0              1.0             0
# 4         26000.0      180        3.0    2.0              2.0             0
# ...           ...      ...        ...    ...              ...           ...
# 11863     12000.0       54        2.0    2.0              1.0             0
# 11864     11500.0       68        2.0    1.0              1.0             0
# 11865     13500.0      120        3.0    1.0              1.0             0
# 11866      9600.0       50        1.0    1.0              1.0             0
# 11867     14150.0      120        3.0    1.0              1.0             0
#
#        es_penthouse  cuenta_con_cocina_integral  cuenta_con_sala  \
# 0                 0                           1                1
# 1                 0                           0                1
# 2                 0                           1                1
# 3                 0                           0                1
# 4                 0                           1                0
# ...             ...                         ...              ...
# 11863             0                           1                1
# 11864             0                           1                1
# 11865             0                           1                1
# 11866             0                           1                1
# 11867             0                           1                1
#
#        cuenta_con_closet  ...  cuenta_con_terraza  cuenta_con_comedor  \
# 0                      0  ...                   0                   1
# 1                      1  ...                   0                   0
# 2                      1  ...                   1                   1
# 3                      0  ...                   0                   1
# 4                      1  ...                   0                   0
# ...                  ...  ...                 ...                 ...
# 11863                  0  ...                   0                   1
# 11864                  0  ...                   0                   1
# 11865                  0  ...                   0                   1
# 11866                  0  ...                   1                   1
# 11867                  0  ...                   0                   1
#
#        cuenta_con_area_de_lavado  cuenta_con_salon_usos_multiples  \
# 0                              0                                0
# 1                              1                                0
# 2                              0                                0
# 3                              0                                0
# 4                              0                                0
# ...                          ...                              ...
# 11863                          0                                0
# 11864                          0                                0
# 11865                          0                                0
# 11866                          0                                0
# 11867                          0                                0
#
#        cuenta_con_mantenimiento_incluido  cuenta_con_vigilancia_24_horas  \
# 0                                      0                               0
# 1                                      1                               0
# 2                                      0                               1
# 3                                      0                               0
# 4                                      0                               1
# ...                                  ...                             ...
# 11863                                  0                               1
# 11864                                  1                               0
# 11865                                  0                               1
# 11866                                  0                               0
# 11867                                  0                               1
#
#                                                direccion  \
# 0      san jeronimo lidice san jeronimo lidice la mag...
# 1      callejon del prado barrio san francisco la mag...
# 2      blvd. adolfo ruiz cortines 2775 san jeronimo l...
# 3      magnolia 26 san jeronimo lidice la magdalena c...
# 4        san marcos 11 pedregal 2 la magdalena contreras
# ...                                                  ...
# 11863  renta depto. san marcos azcapotzalco cdmx san ...
# 11864  av ferrocarriles nacionales 25 santiago ahuizo...
# 11865  45 calzada azcapotzalco la villa santo tomas a...
# 11866                 totonacas 6 tezozomoc azcapotzalco
# 11867  45 calzada azcapotzalco la villa santo tomas a...
#
#                     colonia     cp               municipio
# 0       san jeronimo lidice  10200  la magdalena contreras
# 1                  el prado   9480  la magdalena contreras
# 2      adolfo ruiz cortines   4630  la magdalena contreras
# 3       san jeronimo lidice  10200  la magdalena contreras
# 4                san marcos   2020  la magdalena contreras
# ...                     ...    ...                     ...
# 11863            san marcos   2020            azcapotzalco
# 11864    santiago ahuizotla   2750            azcapotzalco
# 11865           santo tomas   2020            azcapotzalco
# 11866             tezozomoc   2459            azcapotzalco
# 11867           santo tomas   2020            azcapotzalco
#
# [11868 rows x 25 columns]

# %% [markdown]
# ### Read AGEB data with colonia

# %%
data_folder = "../../data/processed/INEGI/colonia"
csv_files = [f for f in os.listdir(data_folder) if f.endswith('.csv')]
print("Archivos encontrados:", list(csv_files))
# Out:
# Archivos encontrados: ['20250925224413_benito_juarez.csv', '20250926110422_cuauhtemoc.csv', '20250926043944_milpa_alta.csv', '20250926223742_venustiano_carranza.csv', '20250929081834_xochimilco.csv', '20250928025355_coyoacan.csv', '20250928113408_alvaro_obregon.csv', '20250926014033_cuajimalpa_de_morelos.csv', '20250926074342_la_magdalena_contreras.csv', '20250927030053_azcapotzalco.csv', '20250927085746_tlahuac.csv', '20250926182507_iztacalco.csv', '20250926143135_miguel_hidalgo.csv']

# %%
len(csv_files)
# Out:
# 13

# %%
data = []
for file in csv_files:
    print(f"\nArchivo: {file}")
    df_tmp = pd.read_csv(os.path.join(data_folder, file), low_memory=False)
    data.append(df_tmp)
# Out:
# Archivo: 20250925224413_benito_juarez.csv
#
# Archivo: 20250926110422_cuauhtemoc.csv
#
# Archivo: 20250926043944_milpa_alta.csv
#
# Archivo: 20250926223742_venustiano_carranza.csv
#
# Archivo: 20250929081834_xochimilco.csv
#
# Archivo: 20250928025355_coyoacan.csv
#
# Archivo: 20250928113408_alvaro_obregon.csv
#
# Archivo: 20250926014033_cuajimalpa_de_morelos.csv
#
# Archivo: 20250926074342_la_magdalena_contreras.csv
#
# Archivo: 20250927030053_azcapotzalco.csv
#
# Archivo: 20250927085746_tlahuac.csv
#
# Archivo: 20250926182507_iztacalco.csv
#
# Archivo: 20250926143135_miguel_hidalgo.csv

# %%
df_ageb = pd.concat(data, ignore_index=True)

# %%
pat = re.compile(r"'neighbourhood':\s*'([^']+)'")
df_ageb['neighbourhood'] = df_ageb['address'].str.extract(pat)

# %%
df_ageb['neighbourhood'].isnull().sum()
# Out:
# 19800

# %%
df_ageb.columns
# Out:
# Index(['ENTIDAD', 'NOM_ENT', 'MUN', 'NOM_MUN', 'LOC', 'NOM_LOC', 'AGEB', 'MZA',
#        'POBTOT', 'POBFEM',
#        ...
#        'NOMREF3', 'lon', 'lat', 'municipio', 'address', 'road', 'quarter',
#        'borough', 'postcode', 'neighbourhood'],
#       dtype='object', length=135)

# %% [markdown]
# ### Read localidades data

# %%
df_loc = pd.read_csv('../../data/raw/localidades/TR_LOCALIDAD_09 2.csv')

# %%
df_loc.columns
# Out:
# Index(['ENT', 'MUN', 'LOC', 'TIPOLOC', 'OTROTIPO_C', 'DIS_TRANS', 'AUTO',
#        'MICRO', 'CAMION', 'TAXI',
#        ...
#        'USOIGL', 'USOFEST', 'USOCOMP', 'USOFAM', 'USOHOG', 'PROBLEMA',
#        'PROBLEMA_O_C', 'POBTOT', 'TAMLOC', 'LOC_LENGUA40PC'],
#       dtype='object', length=162)

# %%
df_loc.head()
# Out:
#    ENT  MUN  LOC  TIPOLOC  OTROTIPO_C  DIS_TRANS  AUTO  MICRO  CAMION  TAXI  \
# 0    9    4   10        2         NaN          3   NaN    NaN     NaN   NaN
# 1    9    4   50        4         NaN          1   1.0    3.0     6.0   7.0
# 2    9    4   54        2         NaN          1   1.0    3.0     6.0   7.0
# 3    9    4   55        2         NaN          1   2.0    3.0     6.0   7.0
# 4    9    4   56        7         NaN          3   NaN    NaN     NaN   NaN
#
#    ...  USOIGL  USOFEST  USOCOMP  USOFAM  USOHOG  PROBLEMA  PROBLEMA_O_C  \
# 0  ...     9.0      9.0      9.0     9.0     9.0         8           NaN
# 1  ...     9.0      9.0      9.0     9.0     9.0         6           NaN
# 2  ...     9.0      9.0      9.0     9.0     9.0         8           NaN
# 3  ...     NaN      NaN      NaN     NaN     NaN         6           NaN
# 4  ...     NaN      NaN      NaN     NaN     NaN         6           NaN
#
#    POBTOT  TAMLOC  LOC_LENGUA40PC
# 0     728       4               3
# 1     486       3               3
# 2    1233       5               3
# 3      80       1               3
# 4     108       2               3
#
# [5 rows x 162 columns]

# %%
df_loc.columns
# Out:
# Index(['ENT', 'MUN', 'LOC', 'TIPOLOC', 'OTROTIPO_C', 'DIS_TRANS', 'AUTO',
#        'MICRO', 'CAMION', 'TAXI',
#        ...
#        'USOIGL', 'USOFEST', 'USOCOMP', 'USOFAM', 'USOHOG', 'PROBLEMA',
#        'PROBLEMA_O_C', 'POBTOT', 'TAMLOC', 'LOC_LENGUA40PC'],
#       dtype='object', length=162)

# %% [markdown]
# ### Read colonias/cp file

# %%
df_cp = pd.read_csv('../../data/raw/CP/CPdescarga - Distrito_Federal.csv')

# %% [markdown]
# ### Join INEGI files

# %%
df_loc.shape
# Out:
# (601, 162)

# %%
df_ageb.shape
# Out:
# (219441, 135)

# %%
set(df_ageb.columns).intersection(set(df_loc.columns))
# Out:
# {'LOC', 'MUN', 'POBTOT'}

# %%
df_loc[(df_loc.LOC == 10)&(df_loc.MUN == 4)]
# Out:
#    ENT  MUN  LOC  TIPOLOC  OTROTIPO_C  DIS_TRANS  AUTO  MICRO  CAMION  TAXI  \
# 0    9    4   10        2         NaN          3   NaN    NaN     NaN   NaN
#
#    ...  USOIGL  USOFEST  USOCOMP  USOFAM  USOHOG  PROBLEMA  PROBLEMA_O_C  \
# 0  ...     9.0      9.0      9.0     9.0     9.0         8           NaN
#
#    POBTOT  TAMLOC  LOC_LENGUA40PC
# 0     728       4               3
#
# [1 rows x 162 columns]

# %%
df_ageb[['LOC','MUN']]
# Out:
#         LOC  MUN
# 0         1   14
# 1         1   14
# 2         1   14
# 3         1   14
# 4         1   14
# ...     ...  ...
# 219436    1   16
# 219437    1   16
# 219438    1   16
# 219439    1   16
# 219440    1   16
#
# [219441 rows x 2 columns]

# %%
df_loc.LOC.value_counts()
# Out:
# LOC
# 140    4
# 112    4
# 113    4
# 135    3
# 198    3
#       ..
# 344    1
# 345    1
# 348    1
# 352    1
# 293    1
# Name: count, Length: 361, dtype: int64

# %%
df_ageb.LOC.value_counts()
# Out:
# LOC
# 1      203039
# 11       3253
# 21       2162
# 24       2108
# 20       2011
# 33       1400
# 17       1249
# 36       1009
# 26        961
# 29        774
# 152       584
# 15        425
# 300       271
# 110       195
# Name: count, dtype: int64

# %%
df_ageb[(df_ageb.LOC == 10)]
# Out:
# Empty DataFrame
# Columns: [ENTIDAD, NOM_ENT, MUN, NOM_MUN, LOC, NOM_LOC, AGEB, MZA, POBTOT, POBFEM, POBMAS, P_0A2, P_0A2_F, P_0A2_M, P_18YMAS, P_18YMAS_F, P_18YMAS_M, P_3A5, P_3A5_F, P_3A5_M, P_6A11, P_6A11_F, P_6A11_M, P_8A14, P_8A14_F, P_8A14_M, P_12A14, P_12A14_F, P_12A14_M, P_15A17, P_15A17_F, P_15A17_M, P_18A24, P_18A24_F, P_18A24_M, P_15A49_F, P_60YMAS, P_60YMAS_F, P_60YMAS_M, POB65_MAS, P18YM_PB, P18YM_PB_F, P18YM_PB_M, TOTHOG, HOGJEF_F, HOGJEF_M, POBHOG, PHOGJEF_F, PHOGJEF_M, VIVTOT, TVIVHAB, TVIVPAR, VIVPAR_HAB, VIVPARH_CV, TVIVPARHAB, VIVPAR_DES, VIVPAR_UT, OCUPVIVPAR, PROM_OCUP, PRO_OCUP_C, VPH_1DOR, VPH_2YMASD, VPH_1CUART, VPH_2CUART, VPH_3YMASC, VPH_C_ELEC, VPH_S_ELEC, VPH_AGUADV, VPH_AEASP, VPH_AGUAFV, VPH_TINACO, VPH_CISTER, VPH_EXCSA, VPH_LETR, VPH_DRENAJ, VPH_NODREN, VPH_C_SERV, VPH_NDEAED, VPH_DSADMA, VPH_NDACMM, VPH_SNBIEN, VPH_REFRI, VPH_LAVAD, VPH_HMICRO, VPH_AUTOM, VPH_MOTO, VPH_BICI, VPH_RADIO, VPH_TV, VPH_PC, VPH_TELEF, VPH_CEL, VPH_INTER, VPH_STVP, VPH_SPMVPI, VPH_CVJ, VPH_SINRTV, VPH_SINLTC, VPH_SINCINT, VPH_SINTIC, ...]
# Index: []
#
# [0 rows x 135 columns]

# %%
#df_inegi = df_ageb.merge(df_loc, on = ['LOC', 'MUN'])

# %% [markdown]
# ### Join all files

# %%
df_web.colonia.value_counts()
# Out:
# colonia
# hidalgo                3445
# cuauhtemoc             1834
# santa fe                645
# cuajimalpa              436
# hipodromo               276
#                        ...
# la palmita                1
# villa de aragon           1
# torres lindavista         1
# infonavit iztacalco       1
# santiago ahuizotla        1
# Name: count, Length: 396, dtype: int64

# %%
df_ageb.neighbourhood.value_counts()
# Out:
# neighbourhood
# Colonia Agrícola Pantitlán                2535
# Colonia Jardín Balbuena                   1365
# Colonia INFONAVIT Sur 20                  1154
# Colonia Kennedy                           1057
# Centro                                     970
#                                           ...
# Colonia Parques del Pedregal                 1
# Colonia Arenal de Guadalupe                  1
# Colonia Fernando Casas Alemán                1
# Colonia San Juan de Aragón 2a. Sección       1
# Colonia San Gabriel                          1
# Name: count, Length: 1295, dtype: int64

# %%
df_ageb['neighbourhood'] = df_ageb['neighbourhood'].apply(estandarizar_texto)
df_ageb['neighbourhood'] = df_ageb['neighbourhood'].str.replace('colonia ' , '').replace('Colonia ' , '')

# %%
df_ageb.neighbourhood.value_counts()
# Out:
# neighbourhood
#                         19800
# agricola pantitlan       2535
# jardin balbuena          1573
# infonavit sur 20         1154
# kennedy                  1057
#                         ...
# arenal de guadalupe         1
# parques del pedregal        1
# mexicaltzingo               1
# sinatel                     1
# san gabriel                 1
# Name: count, Length: 1273, dtype: int64

# %%
df_ageb[df_ageb.neighbourhood == 'hidalgo']
# Out:
#         ENTIDAD           NOM_ENT  MUN         NOM_MUN  LOC         NOM_LOC  \
# 104164        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104165        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104166        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104167        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104168        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104169        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104170        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104171        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104173        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104174        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104175        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104176        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104179        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104180        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104182        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104183        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104184        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104185        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104187        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104188        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104189        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104190        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104191        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104194        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104196        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104197        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104198        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104199        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104200        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104201        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104202        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104203        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104205        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104206        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104207        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104210        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104241        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104243        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104244        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104246        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104247        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104248        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
# 104286        9  Ciudad de México   10  Álvaro Obregón    1  Álvaro Obregón
#
#         AGEB  MZA  POBTOT POBFEM  ...            NOMREF3           lon  \
# 104164  0031    1      85     45  ...          Bondojito  2.792338e+06
# 104165  0031    1      85     45  ...             Bejuco  2.792371e+06
# 104166  0031    1      85     45  ...        Ixmiquilpan  2.792343e+06
# 104167  0031    1      85     45  ...  Huichapan de León  2.792310e+06
# 104168  0031    2      85     48  ...          Bondojito  2.792408e+06
# 104169  0031    2      85     48  ...  Huichapan de León  2.792446e+06
# 104170  0031    2      85     48  ...        Ixmiquilpan  2.792416e+06
# 104171  0031    2      85     48  ...  Florencio Miranda  2.792378e+06
# 104173  0031    3     160     92  ...         Tulancingo  2.792420e+06
# 104174  0031    3     160     92  ...          Bondojito  2.792425e+06
# 104175  0031    3     160     92  ...  Florencio Miranda  2.792387e+06
# 104176  0031    4     206    118  ...           El Chico  2.792426e+06
# 104179  0031    4     206    118  ...  Florencio Miranda  2.792396e+06
# 104180  0031    5     314    153  ...          Bondojito  2.792391e+06
# 104182  0031    5     314    153  ...           El Chico  2.792380e+06
# 104183  0031    5     314    153  ...           El Chico  2.792359e+06
# 104207               Calle Tula     NaN  Álvaro Obregón   1120.0       hidalgo
# 104210  Calle Huichapan de León     NaN  Álvaro Obregón   1120.0       hidalgo
# 104241  Calle Huichapan de León     NaN  Álvaro Obregón   1120.0       hidalgo
# 104243               Calle Tula     NaN  Álvaro Obregón   1120.0       hidalgo
# 104244             Calle Bejuco     NaN  Álvaro Obregón   1120.0       hidalgo
# 104246  Calle Florencio Miranda     NaN  Álvaro Obregón   1120.0       hidalgo
# 104247               Calle Tula     NaN  Álvaro Obregón   1120.0       hidalgo
# 104248  Calle Huichapan de León     NaN  Álvaro Obregón   1120.0       hidalgo
# 104286  Calle Huichapan de León     NaN  Álvaro Obregón   1120.0       hidalgo
#
# [43 rows x 135 columns]

# %%
context = ['ENTIDAD', 'NOM_ENT', 'MUN', 'NOM_MUN', 'LOC', 'NOM_LOC', 'AGEB', 'MZA',
            'key', 'ENTIDAD_fm', 'MUN_fm', 'LOC_fm', 'AGEB_fm', 'MZA_fm', 'CVEVIAL',
            'CVESEG', 'CVEFT', 'NOMVIAL', 'TIPOVIAL', 'CVEVIAL1', 'CVESEG1',
            'CVEREF1', 'TIPOVR1', 'NOMREF1', 'CVEVIAL2', 'CVESEG2', 'CVEREF2',
            'TIPOVR2', 'NOMREF2', 'CVEVIAL3', 'CVESEG3', 'CVEREF3', 'TIPOVR3',
            'NOMREF3', 'lon', 'lat', 'municipio', 'address', 'road', 'quarter',
            'borough', 'postcode', 'neighbourhood']

# %%
cols = list(set(df_ageb.columns)-set(context))

# %%
df_ageb.columns[100:]
# Out:
# Index(['key', 'ENTIDAD_fm', 'MUN_fm', 'LOC_fm', 'AGEB_fm', 'MZA_fm', 'CVEVIAL',
#        'CVESEG', 'CVEFT', 'NOMVIAL', 'TIPOVIAL', 'CVEVIAL1', 'CVESEG1',
#        'CVEREF1', 'TIPOVR1', 'NOMREF1', 'CVEVIAL2', 'CVESEG2', 'CVEREF2',
#        'TIPOVR2', 'NOMREF2', 'CVEVIAL3', 'CVESEG3', 'CVEREF3', 'TIPOVR3',
#        'NOMREF3', 'lon', 'lat', 'municipio', 'address', 'road', 'quarter',
#        'borough', 'postcode', 'neighbourhood'],
#       dtype='object')

# %%
df_ageb[cols] = df_ageb[cols].replace('*',0)
df_ageb[cols] = df_ageb[cols].replace('N/D',0)

# %%
df_ageb[cols] = df_ageb[cols].astype('float64')

# %%
df_ageb = df_ageb[df_ageb.neighbourhood != '']

# %%
df_ageb_grp = df_ageb.groupby('neighbourhood')[cols].mean().reset_index()

# %%
df_ageb_grp.shape
# Out:
# (1272, 93)

# %%
df_ageb_grp
# Out:
#                               neighbourhood  P_12A14_F     TVIVPAR  \
# 0                                10 de mayo   1.583333   44.583333
# 1                          16 de septiembre   5.860465  124.651163
# 2                                19 de mayo   3.782258   47.854839
# 3     1a. seccion del bosque de chapultepec   0.000000    0.000000
# 4                 1a. seccion los cerrillos   9.278132  108.326964
# ...                                     ...        ...         ...
# 1267                             zentlapatl  16.492537  178.562189
# 1268                            zona centro   6.807692   95.153846
# 1269              zona de reserva ecologica   2.010638   31.531915
# 1270                              zona rosa   0.000000   76.333333
# 1271                           zona rustica   5.988679   72.343396
#
#       P18YM_PB_F  VPH_SPMVPI   VPH_MOTO      POBFEM  VIVPAR_HAB  OCUPVIVPAR  \
# 0      30.500000   13.500000   2.666667   65.250000   38.916667  124.166667
# 1     113.255814   56.325581   8.604651  210.767442  111.139535  414.046512
# 2      38.612903   14.145161   3.822581   96.572581   44.072581  189.056452
# 3       0.000000    0.000000   0.000000    0.000000    0.000000    0.000000
# 4      57.316348   10.772824   8.683652  195.766454   96.346072  378.874735
# ...          ...         ...        ...         ...         ...         ...
# 1267  119.333333   40.997512  12.753731  359.218905  163.751244  692.845771
# 1268   53.403846   20.211538   8.653846  156.173077   83.326923  295.250000
# 1269   23.648936    3.797872   2.787234   58.170213   29.276596  111.659574
# 1270   39.666667   39.666667   4.666667   46.000000   57.666667  106.666667
# 1271   47.101887   13.735849   5.958491  130.411321   65.709434  260.660377
#
#           TOTHOG  ...    P_18A24   P_6A11_M  VPH_2YMASD  POB65_MAS  \
# 0      39.000000  ...  12.333333   5.583333   29.166667  14.416667
# 1     123.930233  ...  42.209302  13.813953   83.604651  49.744186
# 2      48.879032  ...  20.959677   7.879032   35.040323  16.580645
# 3       0.000000  ...   0.000000   0.000000    0.000000   0.000000
# 4      97.108280  ...  47.777070  19.855626   61.036093  20.261146
# ...          ...  ...        ...        ...         ...        ...
# 1267  172.223881  ...  80.054726  36.094527  117.353234  42.363184
# 1268   85.326923  ...  33.423077  14.000000   68.865385  28.923077
# 1269   29.404255  ...  12.382979   5.361702   20.617021   8.872340
# 1270   57.666667  ...   8.000000   0.000000   21.000000   8.000000
# 1271   66.083019  ...  29.977358  14.332075   45.328302  15.245283
#
#       VPH_CISTER    P18YM_PB  P18YM_PB_M    P_0A2_F  VPH_NDACMM      POBTOT
# 0      32.416667   61.083333   30.583333   1.500000   24.916667  124.500000
# 1      42.139535  221.023256  107.767442   4.674419   65.395349  414.046512
# 2      11.306452   73.596774   34.983871   2.645161   24.508065  189.056452
# 3       0.000000    0.000000    0.000000   0.000000    0.000000    0.000000
# 4      38.785563  109.953291   52.628450   7.583864   59.653928  378.874735
# ...          ...         ...         ...        ...         ...         ...
# 1267   30.562189  234.353234  115.014925  13.119403  108.149254  692.860697
# 1268   80.365385  105.230769   51.826923   5.557692   63.346154  297.269231
# 1269    8.191489   46.414894   22.744681   1.042553   15.351064  111.659574
# 1270   57.666667   92.333333   52.666667   1.666667   17.000000  106.666667
# 1271   19.143396   91.373585   44.098113   4.332075   37.249057  260.660377
#
# [1272 rows x 93 columns]

# %%
df_ageb_grp.neighbourhood.values
# Out:
# array(['10 de mayo', '16 de septiembre', '19 de mayo', ...,
#        'zona de reserva ecologica', 'zona rosa', 'zona rustica'],
#       dtype=object)

# %%
df_merge = df_web.merge(df_ageb_grp, left_on='colonia', right_on='neighbourhood', how='left', indicator=True)

# %%
df_merge.shape
# Out:
# (11868, 119)

# %%
df_merge.columns
# Out:
# Index(['precio_mxn', 'lote_m2', 'recamaras', 'baños', 'estacionamiento',
#        'es_amueblado', 'es_penthouse', 'cuenta_con_cocina_integral',
#        'cuenta_con_sala', 'cuenta_con_closet',
#        ...
#        'P_6A11_M', 'VPH_2YMASD', 'POB65_MAS', 'VPH_CISTER', 'P18YM_PB',
#        'P18YM_PB_M', 'P_0A2_F', 'VPH_NDACMM', 'POBTOT', '_merge'],
#       dtype='object', length=119)

# %%
df_merge._merge.value_counts()
# Out:
# _merge
# both          10262
# left_only      1606
# right_only        0
# Name: count, dtype: int64

# %%
df_merge[df_merge._merge == 'left_only'][['colonia', 'neighbourhood']]
# Out:
#                       colonia neighbourhood
# 0         san jeronimo lidice           NaN
# 3         san jeronimo lidice           NaN
# 5       san nicolas totolapan           NaN
# 6         san jeronimo lidice           NaN
# 8         san jeronimo lidice           NaN
# ...                       ...           ...
# 11835        lindavista norte           NaN
# 11837        vasco de quiroga           NaN
# 11838       la laguna ticoman           NaN
# 11851  san martin xochinahuac           NaN
# 11861  san martin xochinahuac           NaN
#
# [1606 rows x 2 columns]

# %%
df_merge[df_merge._merge == 'left_only']['colonia'].value_counts()
# Out:
# colonia
# bosque                           197
# polanco v seccion                161
# tlalpan                          130
# polanco iv seccion               121
# del valle sur                     83
#                                 ...
# la magdalena                       1
# centro (area 5)                    1
# infonavit iztacalco                1
# ocotillos del pueblo tetelpan      1
# Zacatenco                          1
# Name: count, Length: 157, dtype: int64

# %%
df_merge = df_merge[df_merge._merge == 'both']

# %%
len(cols)
# Out:
# 92

# %%
df_merge.columns[:50]
# Out:
# Index(['precio_mxn', 'lote_m2', 'recamaras', 'baños', 'estacionamiento',
#        'es_amueblado', 'es_penthouse', 'cuenta_con_cocina_integral',
#        'cuenta_con_sala', 'cuenta_con_closet', 'cuenta_con_balcon',
#        'cuenta_con_gimnasio', 'cuenta_con_alberca', 'cuenta_con_elevador',
#        'cuenta_con_roof_garden', 'cuenta_con_terraza', 'cuenta_con_comedor',
#        'cuenta_con_area_de_lavado', 'cuenta_con_salon_usos_multiples',
#        'cuenta_con_mantenimiento_incluido', 'cuenta_con_vigilancia_24_horas',
#        'direccion', 'colonia', 'cp', 'municipio', 'neighbourhood', 'P_12A14_F',
#        'TVIVPAR', 'P18YM_PB_F', 'VPH_SPMVPI', 'VPH_MOTO', 'POBFEM',
#        'VIVPAR_HAB', 'OCUPVIVPAR', 'TOTHOG', 'PHOGJEF_M', 'VPH_STVP',
#        'VPH_1DOR', 'P_60YMAS', 'VPH_AEASP', 'VPH_S_ELEC', 'P_3A5_F', 'P_0A2_M',
#        'VIVTOT', 'P_60YMAS_F', 'VPH_2CUART', 'P_3A5', 'VPH_CVJ', 'P_8A14',
#        'P_18A24_M'],
#       dtype='object')

# %%
df_merge.to_parquet('../../data/processed/merged_inmuebles24_departamentos_20250927.parquet', index=False)
