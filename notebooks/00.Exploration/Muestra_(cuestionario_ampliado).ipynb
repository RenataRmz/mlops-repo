# %% [markdown]
# <a href="https://colab.research.google.com/github/RenataRmz/mlops-repo/blob/feature-exploration/notebooks/00.Exploration/Muestra_(cuestionario_ampliado).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd

# %%
# Crear una carpeta de trabajo y moverse a ella
os.makedirs("INEGI_Censo2020_CDMX", exist_ok=True)
os.chdir("INEGI_Censo2020_CDMX")

# %%
# ----------------------------
# 1. Descargar los archivos
# ----------------------------
# !wget -O Censo_CDMX.zip "https://www.inegi.org.mx/contenidos/programas/ccpv/2020/microdatos/Censo2020_CA_cdmx_csv.zip"
# !wget -O Clasificaciones.zip "https://www.inegi.org.mx/contenidos/programas/ccpv/2020/microdatos/Censo2020_clasificaciones_CPV_csv.zip"
# Out:
# --2025-08-05 03:02:02--  https://www.inegi.org.mx/contenidos/programas/ccpv/2020/microdatos/Censo2020_CA_cdmx_csv.zip
# Resolving www.inegi.org.mx (www.inegi.org.mx)... 200.23.8.5
# Connecting to www.inegi.org.mx (www.inegi.org.mx)|200.23.8.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10295515 (9.8M) [application/x-zip-compressed]
# Saving to: ‘Censo_CDMX.zip’
#
# Censo_CDMX.zip      100%[===================>]   9.82M  1.56MB/s    in 7.2s
#
# 2025-08-05 03:02:10 (1.36 MB/s) - ‘Censo_CDMX.zip’ saved [10295515/10295515]
#
# --2025-08-05 03:02:10--  https://www.inegi.org.mx/contenidos/programas/ccpv/2020/microdatos/Censo2020_clasificaciones_CPV_csv.zip
# Resolving www.inegi.org.mx (www.inegi.org.mx)... 200.23.8.5
# Connecting to www.inegi.org.mx (www.inegi.org.mx)|200.23.8.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39294 (38K) [application/x-zip-compressed]
# Saving to: ‘Clasificaciones.zip’
#
# ...

# %%
# ----------------------------
# 2. Descomprimir los ZIP
# ----------------------------
# !unzip -o Censo_CDMX.zip -d CDMX
# !unzip -o Clasificaciones.zip -d Clasificaciones
# Out:
# Archive:  Censo_CDMX.zip
#   inflating: CDMX/Migrantes09.CSV
#   inflating: CDMX/Personas09.CSV
#   inflating: CDMX/Viviendas09.CSV
# Archive:  Clasificaciones.zip
#   inflating: Clasificaciones/ACTIVIDAD.csv
#   inflating: Clasificaciones/CARRERA.csv
#   inflating: Clasificaciones/CAUSA_MIG.csv
#   inflating: Clasificaciones/CLASE_VIV.csv
#   inflating: Clasificaciones/ENT.csv
#   inflating: Clasificaciones/ENT_PAIS.csv
#   inflating: Clasificaciones/ESCOACUM.csv
#   inflating: Clasificaciones/INALI.csv
#   inflating: Clasificaciones/MUN.csv
#   inflating: Clasificaciones/OCUPACION.csv
#   inflating: Clasificaciones/PARENTESCO.csv
#   inflating: Clasificaciones/RELIGION.csv

# %%
# ----------------------------
# 3. Cargar los archivos CSV
# ----------------------------
# 3.1 Mostrar los archivos de CDMX
cdmx_files = os.listdir("CDMX")
print("Archivos CDMX:", cdmx_files)
# Out:
# Archivos CDMX: ['Viviendas09.CSV', 'Personas09.CSV', 'Migrantes09.CSV']

# %%
# Cargar Viviendas
viviendas = pd.read_csv("CDMX/Viviendas09.CSV", encoding="latin1")
print("✅ DataFrame 'viviendas' cargado:")
viviendas.head()
# Out:
# ✅ DataFrame 'viviendas' cargado:
#    ENT  MUN  LOC50K       ID_VIV  COBERTURA         ESTRATO  UPM  FACTOR  \
# 0    9    2       1  90020000001          2  09-002-0001-00    1      27
# 1    9    2       1  90020000002          2  09-002-0001-00    1      27
# 2    9    2       1  90020000003          2  09-002-0001-00    1      27
# 3    9    2       1  90020000004          2  09-002-0001-00    1      27
# 4    9    2       1  90020000005          2  09-002-0001-00    1      27
#
#    CLAVIVP  PAREDES  ...  ALIM_ADL1  ALIM_ADL2  ING_ALIM_ADL1  ING_ALIM_ADL2  \
# 0        1      8.0  ...          2          4              2              4
# 1        1      8.0  ...          2          4              2              4
# 2        1      8.0  ...          2          4              2              4
# 3        1      8.0  ...          2          4              2              4
# 4        1      8.0  ...          2          4              2              4
#
# ...

# %%
viviendas.shape
# Out:
# (81527, 83)

# %%
# Cargar Personas
personas = pd.read_csv("CDMX/Personas09.CSV", encoding="latin1")
print("\n✅ DataFrame 'personas' cargado:")
personas.head()
# Out:
# ✅ DataFrame 'personas' cargado:
#    ENT  MUN  LOC50K       ID_VIV        ID_PERSONA  COBERTURA         ESTRATO  \
# 0    9    2       1  90020000001  9002000000100001          2  09-002-0001-00
# 1    9    2       1  90020000001  9002000000100002          2  09-002-0001-00
# 2    9    2       1  90020000001  9002000000100003          2  09-002-0001-00
# 3    9    2       1  90020000001  9002000000100004          2  09-002-0001-00
# 4    9    2       1  90020000001  9002000000100005          2  09-002-0001-00
#
#    UPM  FACTOR  CLAVIVP  ...  HIJOS_SOBREVIV  FECHA_NAC_M  FECHA_NAC_A  \
# 0    1      27        1  ...             3.0          3.0       1980.0
# 1    1      27        1  ...             NaN          NaN          NaN
# 2    1      27        1  ...             2.0         10.0       2005.0
# 3    1      27        1  ...             NaN          NaN          NaN
# 4    1      27        1  ...             NaN          NaN          NaN
#
# ...

# %%
personas.shape
# Out:
# (276007, 91)

# %%
# Cargar Migrantes
migrantes = pd.read_csv("CDMX/Migrantes09.CSV", encoding="latin1")
print("\n✅ DataFrame 'migrantes' cargado:")
migrantes.head()
# Out:
# ✅ DataFrame 'migrantes' cargado:
#    ENT  MUN  LOC50K       ID_VIV  COBERTURA         ESTRATO  UPM  FACTOR  \
# 0    9    2       1  90020000258          2  09-002-0001-00    9      24
# 1    9    2       1  90020000312          2  09-002-0001-00   11      23
# 2    9    2       1  90020000393          2  09-002-0001-00   14      26
# 3    9    2       1  90020000525          2  09-002-0001-00   17      26
# 4    9    2       1  90020000544          2  09-002-0001-00   17      26
#
#    CLAVIVP         ID_MII  ...  MCAUSAEMIG_V  MLUGORI_C  MPAIDES_C  MPAIRES  \
# 0        1  9002000025801  ...           501          9        419        3
# 1        1  9002000031201  ...           102          9        425        2
# 2        4  9002000039301  ...           101          9        330        3
# 3        1  9002000052501  ...           102          9        221        1
# 4        1  9002000054401  ...           101          9        221        1
#
# ...

# %%
migrantes.shape
# Out:
# (1318, 26)

# %%
# 3.2 Cargar clasificaciones a necesidad
# clasif_files = os.listdir("Clasificaciones")
# print("\nArchivos de Clasificaciones:", clasif_files)

# # Cargar todos los CSVs de clasificaciones
# for file in clasif_files:
#     if file.endswith(".csv"):
#         path = os.path.join("Clasificaciones", file)
#         df_clasif = pd.read_csv(path, encoding="latin1")
#         print(f"\nArchivo de Clasificación: {file}")
#         print(df_clasif.head())
# Out:
# Archivos de Clasificaciones: ['ENT_PAIS.csv', 'ENT.csv', 'ESCOACUM.csv', 'CAUSA_MIG.csv', 'PARENTESCO.csv', 'ACTIVIDAD.csv', 'RELIGION.csv', 'CLASE_VIV.csv', 'MUN.csv', 'OCUPACION.csv', 'CARRERA.csv', 'INALI.csv']
#
# Archivo de Clasificación: ENT_PAIS.csv
#    CLAVE           DESCRIPCION
# 0      1        Aguascalientes
# 1      2       Baja California
# 2      3   Baja California Sur
# 3      4              Campeche
# 4      5  Coahuila de Zaragoza
#
# Archivo de Clasificación: ENT.csv
#    CVE_ENT               NOM_ENT
# 0        1        Aguascalientes
# 1        2       Baja California
# 2        3   Baja California Sur
# 3        4              Campeche
# 4        5  Coahuila de Zaragoza
#
# Archivo de Clasificación: ESCOACUM.csv
#    CLAVE         DESCRIPCION  \
# 0      0  0 grados aprobados
# 1      1    1 grado aprobado
# 2      2  2 grados aprobados
# 3      3  3 grados aprobados
# 4      4  4 grados aprobados
#
#                                         EQUIVALENCIA
# ...
